# %%
#from tifffile import imsave, imread
import os
import numpy as np

def load_img(img_dir, img_list):
    images=[]
    for i, image_name in enumerate(img_list):    
        if (image_name.split('.')[1] == 'npy'):
            
            image = np.load(img_dir+image_name)
                      
            images.append(image)
    images = np.array(images)
    
    return(images)

def imageLoader(img_dir, img_list, mask_dir, mask_list, batch_size):

    L = len(img_list)

    #keras needs the generator infinite, so we will use while true  
    while True:

        batch_start = 0
        batch_end = batch_size

        while batch_start < L:
            limit = min(batch_end, L)
                       
            X = load_img(img_dir, img_list[batch_start:limit])
            Y = load_img(mask_dir, mask_list[batch_start:limit])

            yield (X,Y) #a tuple with two numpy arrays with batch_size samples     

            batch_start += batch_size   
            batch_end += batch_size

# %%
import os
import numpy as np
# from custom_datagen import ImageLoader
import tensorflow as tf
import keras
from matplotlib import pyplot as plt
import glob
import random
# Out:
# 2025-04-22 15:28:47.849538: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-22 15:28:47.887185: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_img_dir = "2020_2021_Dataset/images/"
train_mask_dir = "2020_2021_Dataset/masks/"

img_list = os.listdir(train_img_dir)
msk_list = os.listdir(train_mask_dir)

num_images = len(os.listdir(train_img_dir))

img_num = random.randint(0,num_images-1)
test_img = np.load(train_img_dir+img_list[img_num])
test_mask = np.load(train_mask_dir+msk_list[img_num])
test_mask = np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
import pandas as pd
columns = ['0','1', '2', '3']
df = pd.DataFrame(columns=columns)
train_mask_list = sorted(glob.glob('2020_2021_Dataset/masks/*.npy'))
for img in range(len(train_mask_list)):
    print(img)
    temp_image=np.load(train_mask_list[img])
    temp_image = np.argmax(temp_image, axis=3)
    val, counts = np.unique(temp_image, return_counts=True)
    zipped = zip(columns, counts)
    conts_dict = dict(zipped)
    
    df = df.append(conts_dict, ignore_index=True)

label_0 = df['0'].sum()
label_1 = df['1'].sum()
label_2 = df['1'].sum()
label_3 = df['3'].sum()
total_labels = label_0 + label_1 + label_2 + label_3
n_classes = 4
#Class weights claculation: n_samples / (n_classes * n_samples_for_class)
wt0 = round((total_labels/(n_classes*label_0)), 2) #round to 2 decimals
wt1 = round((total_labels/(n_classes*label_1)), 2)
wt2 = round((total_labels/(n_classes*label_2)), 2)
wt3 = round((total_labels/(n_classes*label_3)), 2)

#Weights are: 0.26, 22.53, 22.53, 26.21
#wt0, wt1, wt2, wt3 = 0.26, 22.53, 22.53, 26.21
#These weihts can be used for Dice loss
# Out:
# 0
# 1
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 2
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 3
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 4
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 5
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 6
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 7
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 8
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 9
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 10
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 11
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 12
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 13
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 14
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 15
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 16
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 17
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 18
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 19
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 20
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 21
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 22
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 23
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 24
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 25
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 26
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 27
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 28
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 29
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 30
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 31
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 32
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 33
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 34
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 35
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 36
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 37
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 38
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 39
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 40
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 41
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 42
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 43
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 44
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 45
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 46
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 47
# 48
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 49
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 50
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 51
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 52
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 53
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 54
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 55
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 56
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 57
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 58
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 59
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 60
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 61
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 62
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 63
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 64
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 65
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 66
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 67
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 68
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 69
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 70
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 71
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 72
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 73
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 74
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 75
# 76
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 77
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 78
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 79
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 80
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 81
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 82
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 83
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 84
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 85
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 86
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 87
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 88
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 89
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 90
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 91
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 92
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 93
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 94
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 95
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 96
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 97
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 98
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 99
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 100
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 101
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 102
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 103
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 104
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 105
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 106
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 107
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 108
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 109
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 110
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 111
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 112
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 113
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 114
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 115
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 116
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 117
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 118
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 119
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 120
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 121
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 122
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 123
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 124
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 125
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 126
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 127
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 128
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 129
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 130
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 131
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 132
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 133
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 134
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 135
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 136
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 137
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 138
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 139
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 140
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 141
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 142
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 143
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 144
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 145
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 146
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 147
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 148
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 149
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 150
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 151
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 152
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 153
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 154
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 155
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 156
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 157
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 158
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 159
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 160
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 161
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 162
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 163
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 164
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 165
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 166
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 167
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 168
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 169
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 170
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 171
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 172
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 173
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 174
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 175
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 176
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 177
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 178
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 179
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 180
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 181
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 182
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 183
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 184
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 185
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 186
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 187
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 188
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 189
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 190
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 191
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 192
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 193
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 194
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 195
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 196
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 197
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 198
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 199
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 200
# 201
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 202
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 203
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 204
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 205
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 206
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 207
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 208
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 209
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 210
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 211
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 212
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 213
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 214
# ...
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1264
# 1265
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1266
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1267
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1268
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1269
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1270
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1271
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1272
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1273
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1274
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1275
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1276
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1277
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1278
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1279
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1280
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1281
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1282
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1283
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1284
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1285
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1286
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1287
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1288
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1289
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1290
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1291
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1292
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1293
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1294
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1295
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1296
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1297
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1298
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1299
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1300
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1301
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1302
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1303
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1304
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1305
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1306
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1307
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1308
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1309
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1310
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1311
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1312
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1313
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1314
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1315
# 1316
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1317
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1318
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1319
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1320
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1321
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1322
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1323
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1324
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1325
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1326
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1327
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1328
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1329
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1330
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1331
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1332
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1333
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1334
# /tmp/ipykernel_26662/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)

# %%
#Define the image generators for training and validation

train_img_dir = "2020_2021_Dataset/images/"
train_mask_dir = "2020_2021_Dataset/masks/"

val_img_dir = "2020_2021_Validation/images/"
val_mask_dir = "2020_2021_Validation/masks/"

train_img_list=os.listdir(train_img_dir)
train_mask_list = os.listdir(train_mask_dir)

val_img_list=os.listdir(val_img_dir)
val_mask_list = os.listdir(val_mask_dir)

# %%
batch_size = 2

train_img_datagen = imageLoader(train_img_dir, train_img_list, 
                                train_mask_dir, train_mask_list, batch_size)

val_img_datagen = imageLoader(val_img_dir, val_img_list, 
                                val_mask_dir, val_mask_list, batch_size)

#Verify generator.... In python 3 next() is renamed as __next__()
img, msk = train_img_datagen.__next__()

img_num = random.randint(0,img.shape[0]-1)
test_img=img[img_num]
test_mask=msk[img_num]
test_mask=np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
import tensorflow as tf
print(tf.__version__)
import keras
print(keras.__version__)
# Out:
# 2.12.0
# 2.12.0

# %%
#Define loss, metrics and optimizer to be used for training
wt0, wt1, wt2, wt3 = 0.25,0.25,0.25,0.25
import segmentation_models_3D as sm
dice_loss = sm.losses.DiceLoss(class_weights=np.array([wt0, wt1, wt2, wt3])) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

metrics = ['accuracy', sm.metrics.IOUScore(threshold=0.5)]

LR = 0.0001
optim = keras.optimizers.Adam(LR)
# Out:
# Segmentation Models: using `keras` framework.

# %%
from keras.models import Model
from keras.layers import Input, Conv3D, MaxPooling3D, concatenate, Conv3DTranspose, BatchNormalization, Dropout, Lambda
from keras.optimizers import Adam
from keras.metrics import MeanIoU

kernel_initializer =  'he_uniform' #Try others if you want

def simple_unet_model(IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS, num_classes):
#Build the model
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(s)
    c1 = Dropout(0.1)(c1)
    c1 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c1)
    p1 = MaxPooling3D((2, 2, 2))(c1)
    
    c2 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c2)
    p2 = MaxPooling3D((2, 2, 2))(c2)
     
    c3 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c3)
    p3 = MaxPooling3D((2, 2, 2))(c3)
     
    c4 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c4)
    p4 = MaxPooling3D(pool_size=(2, 2, 2))(c4)
     
    c5 = Conv3D(256, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv3D(256, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c5)
    
    #Expansive path 
    u6 = Conv3DTranspose(128, (2, 2, 2), strides=(2, 2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c6)
     
    u7 = Conv3DTranspose(64, (2, 2, 2), strides=(2, 2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c7)
     
    u8 = Conv3DTranspose(32, (2, 2, 2), strides=(2, 2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c8)
     
    u9 = Conv3DTranspose(16, (2, 2, 2), strides=(2, 2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1])
    c9 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c9)
     
    outputs = Conv3D(num_classes, (1, 1, 1), activation='softmax')(c9)
     
    model = Model(inputs=[inputs], outputs=[outputs])
    #compile model outside of this function to make it flexible. 
    model.summary()
    
    return model

# %%
#Fit the model 

steps_per_epoch = len(train_img_list)//batch_size
val_steps_per_epoch = len(val_img_list)//batch_size


# from simple_3d_unet import simple_unet_model

model = simple_unet_model(IMG_HEIGHT=128, 
                          IMG_WIDTH=128, 
                          IMG_DEPTH=128, 
                          IMG_CHANNELS=3, 
                          num_classes=4)

model.compile(optimizer = optim, loss=total_loss, metrics=metrics)
print(model.summary())

print(model.input_shape)
print(model.output_shape)

history=model.fit(train_img_datagen,
          steps_per_epoch=steps_per_epoch,
          epochs=150,
          verbose=1,
          validation_data=val_img_datagen,
          validation_steps=val_steps_per_epoch,
          )

model.save('brats_2020_2021_3d_first.hdf5')
# Out:
# 2025-04-22 15:29:48.445291: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46551 MB memory:  -> device: 0, name: NVIDIA RTX 6000 Ada Generation, pci bus id: 0000:c1:00.0, compute capability: 8.9
# 2025-04-22 15:29:48.446905: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46551 MB memory:  -> device: 1, name: NVIDIA RTX 6000 Ada Generation, pci bus id: 0000:e1:00.0, compute capability: 8.9
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 28, 3)]
#
#  conv3d (Conv3D)                (None, 128, 128, 12  1312        ['input_1[0][0]']
#                                 8, 16)
#
#  dropout (Dropout)              (None, 128, 128, 12  0           ['conv3d[0][0]']
#                                 8, 16)
#
#  conv3d_1 (Conv3D)              (None, 128, 128, 12  6928        ['dropout[0][0]']
#                                 8, 16)
#
#  max_pooling3d (MaxPooling3D)   (None, 64, 64, 64,   0           ['conv3d_1[0][0]']
#                                 16)
#
#  conv3d_2 (Conv3D)              (None, 64, 64, 64,   13856       ['max_pooling3d[0][0]']
#                                 32)
#
#  dropout_1 (Dropout)            (None, 64, 64, 64,   0           ['conv3d_2[0][0]']
#                                 32)
#
#  conv3d_3 (Conv3D)              (None, 64, 64, 64,   27680       ['dropout_1[0][0]']
#                                 32)
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 32, 32, 32,   0          ['conv3d_3[0][0]']
#                                 32)
#
#  conv3d_4 (Conv3D)              (None, 32, 32, 32,   55360       ['max_pooling3d_1[0][0]']
#                                 64)
#
#  dropout_2 (Dropout)            (None, 32, 32, 32,   0           ['conv3d_4[0][0]']
#                                 64)
#
#  conv3d_5 (Conv3D)              (None, 32, 32, 32,   110656      ['dropout_2[0][0]']
#                                 64)
#
#  max_pooling3d_2 (MaxPooling3D)  (None, 16, 16, 16,   0          ['conv3d_5[0][0]']
#                                 64)
#
#  conv3d_6 (Conv3D)              (None, 16, 16, 16,   221312      ['max_pooling3d_2[0][0]']
#                                 128)
#
#  dropout_3 (Dropout)            (None, 16, 16, 16,   0           ['conv3d_6[0][0]']
#                                 128)
#
#  conv3d_7 (Conv3D)              (None, 16, 16, 16,   442496      ['dropout_3[0][0]']
#                                 128)
#
#  max_pooling3d_3 (MaxPooling3D)  (None, 8, 8, 8, 128  0          ['conv3d_7[0][0]']
#                                 )
#
#  conv3d_8 (Conv3D)              (None, 8, 8, 8, 256  884992      ['max_pooling3d_3[0][0]']
#                                 )
#
#  dropout_4 (Dropout)            (None, 8, 8, 8, 256  0           ['conv3d_8[0][0]']
#                                 )
#
#  conv3d_9 (Conv3D)              (None, 8, 8, 8, 256  1769728     ['dropout_4[0][0]']
#                                 )
#
#  conv3d_transpose (Conv3DTransp  (None, 16, 16, 16,   262272     ['conv3d_9[0][0]']
#  ose)                           128)
#
#  concatenate (Concatenate)      (None, 16, 16, 16,   0           ['conv3d_transpose[0][0]',
#                                 256)                              'conv3d_7[0][0]']
#
#  conv3d_10 (Conv3D)             (None, 16, 16, 16,   884864      ['concatenate[0][0]']
#                                 128)
#
#  dropout_5 (Dropout)            (None, 16, 16, 16,   0           ['conv3d_10[0][0]']
#                                 128)
#
#  conv3d_11 (Conv3D)             (None, 16, 16, 16,   442496      ['dropout_5[0][0]']
#                                 128)
#
#  conv3d_transpose_1 (Conv3DTran  (None, 32, 32, 32,   65600      ['conv3d_11[0][0]']
#  spose)                         64)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_1[0][0]',
#                                 128)                              'conv3d_5[0][0]']
#
#  conv3d_12 (Conv3D)             (None, 32, 32, 32,   221248      ['concatenate_1[0][0]']
#                                 64)
#
#  dropout_6 (Dropout)            (None, 32, 32, 32,   0           ['conv3d_12[0][0]']
#                                 64)
#
#  conv3d_13 (Conv3D)             (None, 32, 32, 32,   110656      ['dropout_6[0][0]']
#                                 64)
#
#  conv3d_transpose_2 (Conv3DTran  (None, 64, 64, 64,   16416      ['conv3d_13[0][0]']
#  spose)                         32)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64,   0           ['conv3d_transpose_2[0][0]',
#                                 64)                               'conv3d_3[0][0]']
#
#  conv3d_14 (Conv3D)             (None, 64, 64, 64,   55328       ['concatenate_2[0][0]']
#                                 32)
#
#  dropout_7 (Dropout)            (None, 64, 64, 64,   0           ['conv3d_14[0][0]']
#                                 32)
#
#  conv3d_15 (Conv3D)             (None, 64, 64, 64,   27680       ['dropout_7[0][0]']
#                                 32)
#
#  conv3d_transpose_3 (Conv3DTran  (None, 128, 128, 12  4112       ['conv3d_15[0][0]']
#  spose)                         8, 16)
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 12  0           ['conv3d_transpose_3[0][0]',
#                                 8, 32)                            'conv3d_1[0][0]']
#
#  conv3d_16 (Conv3D)             (None, 128, 128, 12  13840       ['concatenate_3[0][0]']
#                                 8, 16)
#
#  dropout_8 (Dropout)            (None, 128, 128, 12  0           ['conv3d_16[0][0]']
#                                 8, 16)
#
#  conv3d_17 (Conv3D)             (None, 128, 128, 12  6928        ['dropout_8[0][0]']
#                                 8, 16)
#
#  conv3d_18 (Conv3D)             (None, 128, 128, 12  68          ['conv3d_17[0][0]']
#                                 8, 4)
#
# ==================================================================================================
# Total params: 5,645,828
# Trainable params: 5,645,828
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 28, 3)]
#
#  conv3d (Conv3D)                (None, 128, 128, 12  1312        ['input_1[0][0]']
#                                 8, 16)
#
#  dropout (Dropout)              (None, 128, 128, 12  0           ['conv3d[0][0]']
#                                 8, 16)
#
#  conv3d_1 (Conv3D)              (None, 128, 128, 12  6928        ['dropout[0][0]']
#                                 8, 16)
#
#  max_pooling3d (MaxPooling3D)   (None, 64, 64, 64,   0           ['conv3d_1[0][0]']
#                                 16)
#
#  conv3d_2 (Conv3D)              (None, 64, 64, 64,   13856       ['max_pooling3d[0][0]']
#                                 32)
#
#  dropout_1 (Dropout)            (None, 64, 64, 64,   0           ['conv3d_2[0][0]']
#                                 32)
#
#  conv3d_3 (Conv3D)              (None, 64, 64, 64,   27680       ['dropout_1[0][0]']
#                                 32)
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 32, 32, 32,   0          ['conv3d_3[0][0]']
#                                 32)
#
#  conv3d_4 (Conv3D)              (None, 32, 32, 32,   55360       ['max_pooling3d_1[0][0]']
#                                 64)
#
#  dropout_2 (Dropout)            (None, 32, 32, 32,   0           ['conv3d_4[0][0]']
#                                 64)
#
#  conv3d_5 (Conv3D)              (None, 32, 32, 32,   110656      ['dropout_2[0][0]']
#                                 64)
#
#  max_pooling3d_2 (MaxPooling3D)  (None, 16, 16, 16,   0          ['conv3d_5[0][0]']
#                                 64)
#
#  conv3d_6 (Conv3D)              (None, 16, 16, 16,   221312      ['max_pooling3d_2[0][0]']
#                                 128)
#
#  dropout_3 (Dropout)            (None, 16, 16, 16,   0           ['conv3d_6[0][0]']
#                                 128)
#
#  conv3d_7 (Conv3D)              (None, 16, 16, 16,   442496      ['dropout_3[0][0]']
#                                 128)
#
#  max_pooling3d_3 (MaxPooling3D)  (None, 8, 8, 8, 128  0          ['conv3d_7[0][0]']
#                                 )
#
#  conv3d_8 (Conv3D)              (None, 8, 8, 8, 256  884992      ['max_pooling3d_3[0][0]']
#                                 )
#
#  dropout_4 (Dropout)            (None, 8, 8, 8, 256  0           ['conv3d_8[0][0]']
#                                 )
#
#  conv3d_9 (Conv3D)              (None, 8, 8, 8, 256  1769728     ['dropout_4[0][0]']
#                                 )
#
#  conv3d_transpose (Conv3DTransp  (None, 16, 16, 16,   262272     ['conv3d_9[0][0]']
#  ose)                           128)
#
#  concatenate (Concatenate)      (None, 16, 16, 16,   0           ['conv3d_transpose[0][0]',
#                                 256)                              'conv3d_7[0][0]']
#
#  conv3d_10 (Conv3D)             (None, 16, 16, 16,   884864      ['concatenate[0][0]']
#                                 128)
#
#  dropout_5 (Dropout)            (None, 16, 16, 16,   0           ['conv3d_10[0][0]']
#                                 128)
#
#  conv3d_11 (Conv3D)             (None, 16, 16, 16,   442496      ['dropout_5[0][0]']
#                                 128)
#
#  conv3d_transpose_1 (Conv3DTran  (None, 32, 32, 32,   65600      ['conv3d_11[0][0]']
#  spose)                         64)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_1[0][0]',
#                                 128)                              'conv3d_5[0][0]']
#
#  conv3d_12 (Conv3D)             (None, 32, 32, 32,   221248      ['concatenate_1[0][0]']
#                                 64)
#
#  dropout_6 (Dropout)            (None, 32, 32, 32,   0           ['conv3d_12[0][0]']
#                                 64)
#
#  conv3d_13 (Conv3D)             (None, 32, 32, 32,   110656      ['dropout_6[0][0]']
#                                 64)
#
#  conv3d_transpose_2 (Conv3DTran  (None, 64, 64, 64,   16416      ['conv3d_13[0][0]']
#  spose)                         32)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64,   0           ['conv3d_transpose_2[0][0]',
#                                 64)                               'conv3d_3[0][0]']
#
#  conv3d_14 (Conv3D)             (None, 64, 64, 64,   55328       ['concatenate_2[0][0]']
#                                 32)
#
#  dropout_7 (Dropout)            (None, 64, 64, 64,   0           ['conv3d_14[0][0]']
#                                 32)
#
#  conv3d_15 (Conv3D)             (None, 64, 64, 64,   27680       ['dropout_7[0][0]']
#                                 32)
#
#  conv3d_transpose_3 (Conv3DTran  (None, 128, 128, 12  4112       ['conv3d_15[0][0]']
#  spose)                         8, 16)
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 12  0           ['conv3d_transpose_3[0][0]',
#                                 8, 32)                            'conv3d_1[0][0]']
#
#  conv3d_16 (Conv3D)             (None, 128, 128, 12  13840       ['concatenate_3[0][0]']
#                                 8, 16)
#
#  dropout_8 (Dropout)            (None, 128, 128, 12  0           ['conv3d_16[0][0]']
#                                 8, 16)
#
#  conv3d_17 (Conv3D)             (None, 128, 128, 12  6928        ['dropout_8[0][0]']
#                                 8, 16)
#
#  conv3d_18 (Conv3D)             (None, 128, 128, 12  68          ['conv3d_17[0][0]']
#                                 8, 4)
#
# ==================================================================================================
# Total params: 5,645,828
# Trainable params: 5,645,828
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# (None, 128, 128, 128, 3)
# (None, 128, 128, 128, 4)
# Epoch 1/150
# 2025-04-22 15:29:51.221933: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2025-04-22 15:29:52.742516: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8700
# 667/667 [==============================] - ETA: 0s - loss: 0.9108 - accuracy: 0.9409 - iou_score: 0.3270
# 2025-04-22 15:52:08.559215: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 667/667 [==============================] - 1479s 2s/step - loss: 0.9108 - accuracy: 0.9409 - iou_score: 0.3270 - val_loss: 0.9149 - val_accuracy: 0.9516 - val_iou_score: 0.3590
# Epoch 2/150
# 667/667 [==============================] - 84s 126ms/step - loss: 0.8661 - accuracy: 0.9645 - iou_score: 0.4845 - val_loss: 0.8940 - val_accuracy: 0.9573 - val_iou_score: 0.4176
# Epoch 3/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.8418 - accuracy: 0.9721 - iou_score: 0.5675 - val_loss: 0.8794 - val_accuracy: 0.9596 - val_iou_score: 0.4665
# Epoch 4/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.8234 - accuracy: 0.9777 - iou_score: 0.6347 - val_loss: 0.8645 - val_accuracy: 0.9590 - val_iou_score: 0.5093
# Epoch 5/150
# 667/667 [==============================] - 86s 129ms/step - loss: 0.8135 - accuracy: 0.9803 - iou_score: 0.6738 - val_loss: 0.8619 - val_accuracy: 0.9587 - val_iou_score: 0.5195
# Epoch 6/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.8075 - accuracy: 0.9823 - iou_score: 0.6980 - val_loss: 0.8593 - val_accuracy: 0.9595 - val_iou_score: 0.5303
# Epoch 7/150
# 667/667 [==============================] - 85s 128ms/step - loss: 0.8047 - accuracy: 0.9830 - iou_score: 0.7104 - val_loss: 0.8582 - val_accuracy: 0.9570 - val_iou_score: 0.5337
# Epoch 8/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.8012 - accuracy: 0.9843 - iou_score: 0.7248 - val_loss: 0.8510 - val_accuracy: 0.9675 - val_iou_score: 0.5575
# Epoch 9/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.8006 - accuracy: 0.9842 - iou_score: 0.7294 - val_loss: 0.8465 - val_accuracy: 0.9710 - val_iou_score: 0.5728
# Epoch 10/150
# 667/667 [==============================] - 88s 132ms/step - loss: 0.7973 - accuracy: 0.9856 - iou_score: 0.7421 - val_loss: 0.8462 - val_accuracy: 0.9710 - val_iou_score: 0.5739
# Epoch 11/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7947 - accuracy: 0.9865 - iou_score: 0.7529 - val_loss: 0.8421 - val_accuracy: 0.9729 - val_iou_score: 0.5889
# Epoch 12/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7954 - accuracy: 0.9862 - iou_score: 0.7500 - val_loss: 0.8411 - val_accuracy: 0.9723 - val_iou_score: 0.5918
# Epoch 13/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7921 - accuracy: 0.9872 - iou_score: 0.7646 - val_loss: 0.8401 - val_accuracy: 0.9707 - val_iou_score: 0.5962
# Epoch 14/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7925 - accuracy: 0.9871 - iou_score: 0.7636 - val_loss: 0.8449 - val_accuracy: 0.9671 - val_iou_score: 0.5804
# Epoch 15/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7914 - accuracy: 0.9874 - iou_score: 0.7684 - val_loss: 0.8450 - val_accuracy: 0.9664 - val_iou_score: 0.5818
# Epoch 16/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7903 - accuracy: 0.9878 - iou_score: 0.7727 - val_loss: 0.8456 - val_accuracy: 0.9619 - val_iou_score: 0.5784
# Epoch 17/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7884 - accuracy: 0.9884 - iou_score: 0.7814 - val_loss: 0.8446 - val_accuracy: 0.9639 - val_iou_score: 0.5822
# Epoch 18/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7880 - accuracy: 0.9885 - iou_score: 0.7836 - val_loss: 0.8447 - val_accuracy: 0.9617 - val_iou_score: 0.5842
# Epoch 19/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7876 - accuracy: 0.9887 - iou_score: 0.7853 - val_loss: 0.8412 - val_accuracy: 0.9660 - val_iou_score: 0.5950
# Epoch 20/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7857 - accuracy: 0.9893 - iou_score: 0.7939 - val_loss: 0.8357 - val_accuracy: 0.9735 - val_iou_score: 0.6156
# Epoch 21/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7850 - accuracy: 0.9895 - iou_score: 0.7976 - val_loss: 0.8363 - val_accuracy: 0.9732 - val_iou_score: 0.6139
# Epoch 22/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7858 - accuracy: 0.9892 - iou_score: 0.7943 - val_loss: 0.8367 - val_accuracy: 0.9748 - val_iou_score: 0.6149
# Epoch 23/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7843 - accuracy: 0.9897 - iou_score: 0.8005 - val_loss: 0.8314 - val_accuracy: 0.9764 - val_iou_score: 0.6309
# Epoch 24/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7835 - accuracy: 0.9900 - iou_score: 0.8046 - val_loss: 0.8294 - val_accuracy: 0.9762 - val_iou_score: 0.6388
# Epoch 25/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7826 - accuracy: 0.9902 - iou_score: 0.8089 - val_loss: 0.8306 - val_accuracy: 0.9765 - val_iou_score: 0.6328
# Epoch 26/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7822 - accuracy: 0.9904 - iou_score: 0.8110 - val_loss: 0.8262 - val_accuracy: 0.9777 - val_iou_score: 0.6489
# Epoch 27/150
# 667/667 [==============================] - 86s 130ms/step - loss: 0.7811 - accuracy: 0.9907 - iou_score: 0.8159 - val_loss: 0.8300 - val_accuracy: 0.9774 - val_iou_score: 0.6370
# Epoch 28/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7813 - accuracy: 0.9906 - iou_score: 0.8156 - val_loss: 0.8253 - val_accuracy: 0.9776 - val_iou_score: 0.6530
# Epoch 29/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7804 - accuracy: 0.9909 - iou_score: 0.8196 - val_loss: 0.8229 - val_accuracy: 0.9783 - val_iou_score: 0.6625
# Epoch 30/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7807 - accuracy: 0.9909 - iou_score: 0.8179 - val_loss: 0.8244 - val_accuracy: 0.9781 - val_iou_score: 0.6584
# Epoch 31/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7792 - accuracy: 0.9913 - iou_score: 0.8254 - val_loss: 0.8233 - val_accuracy: 0.9783 - val_iou_score: 0.6618
# Epoch 32/150
# 667/667 [==============================] - 86s 130ms/step - loss: 0.7793 - accuracy: 0.9913 - iou_score: 0.8248 - val_loss: 0.8215 - val_accuracy: 0.9787 - val_iou_score: 0.6686
# Epoch 33/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7790 - accuracy: 0.9913 - iou_score: 0.8265 - val_loss: 0.8231 - val_accuracy: 0.9788 - val_iou_score: 0.6644
# Epoch 34/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7800 - accuracy: 0.9910 - iou_score: 0.8217 - val_loss: 0.8365 - val_accuracy: 0.9743 - val_iou_score: 0.6169
# Epoch 35/150
# 667/667 [==============================] - 86s 130ms/step - loss: 0.7788 - accuracy: 0.9913 - iou_score: 0.8276 - val_loss: 0.8200 - val_accuracy: 0.9782 - val_iou_score: 0.6746
# Epoch 36/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7776 - accuracy: 0.9917 - iou_score: 0.8334 - val_loss: 0.8186 - val_accuracy: 0.9796 - val_iou_score: 0.6803
# Epoch 37/150
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7777 - accuracy: 0.9917 - iou_score: 0.8333 - val_loss: 0.8191 - val_accuracy: 0.9788 - val_iou_score: 0.6774
# Epoch 38/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7772 - accuracy: 0.9919 - iou_score: 0.8355 - val_loss: 0.8201 - val_accuracy: 0.9792 - val_iou_score: 0.6748
# Epoch 39/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7772 - accuracy: 0.9918 - iou_score: 0.8357 - val_loss: 0.8314 - val_accuracy: 0.9759 - val_iou_score: 0.6338
# Epoch 40/150
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7773 - accuracy: 0.9917 - iou_score: 0.8350 - val_loss: 0.8160 - val_accuracy: 0.9805 - val_iou_score: 0.6906
# Epoch 41/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7770 - accuracy: 0.9918 - iou_score: 0.8366 - val_loss: 0.8157 - val_accuracy: 0.9806 - val_iou_score: 0.6933
# Epoch 42/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7769 - accuracy: 0.9918 - iou_score: 0.8371 - val_loss: 0.8177 - val_accuracy: 0.9803 - val_iou_score: 0.6852
# Epoch 43/150
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7768 - accuracy: 0.9918 - iou_score: 0.8380 - val_loss: 0.8185 - val_accuracy: 0.9807 - val_iou_score: 0.6824
# Epoch 44/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7766 - accuracy: 0.9919 - iou_score: 0.8385 - val_loss: 0.8208 - val_accuracy: 0.9796 - val_iou_score: 0.6700
# Epoch 45/150
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7763 - accuracy: 0.9920 - iou_score: 0.8403 - val_loss: 0.8159 - val_accuracy: 0.9810 - val_iou_score: 0.6918
# Epoch 46/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7755 - accuracy: 0.9923 - iou_score: 0.8444 - val_loss: 0.8142 - val_accuracy: 0.9807 - val_iou_score: 0.6978
# Epoch 47/150
# 667/667 [==============================] - 86s 130ms/step - loss: 0.7754 - accuracy: 0.9923 - iou_score: 0.8451 - val_loss: 0.8167 - val_accuracy: 0.9801 - val_iou_score: 0.6901
# Epoch 48/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7759 - accuracy: 0.9922 - iou_score: 0.8424 - val_loss: 0.8240 - val_accuracy: 0.9771 - val_iou_score: 0.6606
# Epoch 49/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7753 - accuracy: 0.9924 - iou_score: 0.8450 - val_loss: 0.8147 - val_accuracy: 0.9807 - val_iou_score: 0.6969
# Epoch 50/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7746 - accuracy: 0.9926 - iou_score: 0.8490 - val_loss: 0.8171 - val_accuracy: 0.9794 - val_iou_score: 0.6883
# Epoch 51/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7744 - accuracy: 0.9927 - iou_score: 0.8502 - val_loss: 0.8128 - val_accuracy: 0.9812 - val_iou_score: 0.7061
# Epoch 52/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7740 - accuracy: 0.9928 - iou_score: 0.8520 - val_loss: 0.8125 - val_accuracy: 0.9812 - val_iou_score: 0.7069
# Epoch 53/150
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7743 - accuracy: 0.9927 - iou_score: 0.8503 - val_loss: 0.8162 - val_accuracy: 0.9807 - val_iou_score: 0.6904
# Epoch 54/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7740 - accuracy: 0.9929 - iou_score: 0.8522 - val_loss: 0.8120 - val_accuracy: 0.9817 - val_iou_score: 0.7097
# Epoch 55/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7738 - accuracy: 0.9929 - iou_score: 0.8532 - val_loss: 0.8107 - val_accuracy: 0.9825 - val_iou_score: 0.7140
# Epoch 56/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7736 - accuracy: 0.9930 - iou_score: 0.8545 - val_loss: 0.8110 - val_accuracy: 0.9823 - val_iou_score: 0.7133
# Epoch 57/150
# 667/667 [==============================] - 86s 130ms/step - loss: 0.7734 - accuracy: 0.9929 - iou_score: 0.8555 - val_loss: 0.8101 - val_accuracy: 0.9827 - val_iou_score: 0.7162
# Epoch 58/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7735 - accuracy: 0.9930 - iou_score: 0.8547 - val_loss: 0.8120 - val_accuracy: 0.9823 - val_iou_score: 0.7088
# Epoch 59/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7736 - accuracy: 0.9928 - iou_score: 0.8541 - val_loss: 0.8110 - val_accuracy: 0.9829 - val_iou_score: 0.7120
# Epoch 60/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7731 - accuracy: 0.9931 - iou_score: 0.8571 - val_loss: 0.8099 - val_accuracy: 0.9830 - val_iou_score: 0.7177
# Epoch 61/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7730 - accuracy: 0.9931 - iou_score: 0.8577 - val_loss: 0.8078 - val_accuracy: 0.9833 - val_iou_score: 0.7258
# Epoch 62/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7730 - accuracy: 0.9931 - iou_score: 0.8577 - val_loss: 0.8106 - val_accuracy: 0.9824 - val_iou_score: 0.7149
# Epoch 63/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7728 - accuracy: 0.9932 - iou_score: 0.8586 - val_loss: 0.8120 - val_accuracy: 0.9822 - val_iou_score: 0.7090
# Epoch 64/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7725 - accuracy: 0.9933 - iou_score: 0.8600 - val_loss: 0.8073 - val_accuracy: 0.9828 - val_iou_score: 0.7282
# Epoch 65/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7726 - accuracy: 0.9932 - iou_score: 0.8591 - val_loss: 0.8088 - val_accuracy: 0.9822 - val_iou_score: 0.7218
# Epoch 66/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7724 - accuracy: 0.9933 - iou_score: 0.8607 - val_loss: 0.8085 - val_accuracy: 0.9828 - val_iou_score: 0.7239
# Epoch 67/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7733 - accuracy: 0.9929 - iou_score: 0.8567 - val_loss: 0.8235 - val_accuracy: 0.9785 - val_iou_score: 0.6638
# Epoch 68/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7738 - accuracy: 0.9927 - iou_score: 0.8531 - val_loss: 0.8068 - val_accuracy: 0.9837 - val_iou_score: 0.7305
# Epoch 69/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7725 - accuracy: 0.9931 - iou_score: 0.8602 - val_loss: 0.8075 - val_accuracy: 0.9836 - val_iou_score: 0.7274
# Epoch 70/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7718 - accuracy: 0.9934 - iou_score: 0.8639 - val_loss: 0.8068 - val_accuracy: 0.9840 - val_iou_score: 0.7304
# Epoch 71/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7714 - accuracy: 0.9936 - iou_score: 0.8661 - val_loss: 0.8061 - val_accuracy: 0.9838 - val_iou_score: 0.7349
# Epoch 72/150
# 667/667 [==============================] - 85s 128ms/step - loss: 0.7712 - accuracy: 0.9937 - iou_score: 0.8673 - val_loss: 0.8061 - val_accuracy: 0.9839 - val_iou_score: 0.7335
# Epoch 73/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7714 - accuracy: 0.9936 - iou_score: 0.8660 - val_loss: 0.8109 - val_accuracy: 0.9827 - val_iou_score: 0.7136
# Epoch 74/150
# 667/667 [==============================] - 86s 130ms/step - loss: 0.7719 - accuracy: 0.9935 - iou_score: 0.8634 - val_loss: 0.8064 - val_accuracy: 0.9838 - val_iou_score: 0.7334
# Epoch 75/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7710 - accuracy: 0.9937 - iou_score: 0.8680 - val_loss: 0.8060 - val_accuracy: 0.9838 - val_iou_score: 0.7355
# Epoch 76/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7710 - accuracy: 0.9937 - iou_score: 0.8682 - val_loss: 0.8032 - val_accuracy: 0.9844 - val_iou_score: 0.7474
# Epoch 77/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7710 - accuracy: 0.9937 - iou_score: 0.8685 - val_loss: 0.8036 - val_accuracy: 0.9845 - val_iou_score: 0.7448
# Epoch 78/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7709 - accuracy: 0.9938 - iou_score: 0.8686 - val_loss: 0.8040 - val_accuracy: 0.9840 - val_iou_score: 0.7469
# Epoch 79/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7708 - accuracy: 0.9937 - iou_score: 0.8692 - val_loss: 0.8083 - val_accuracy: 0.9828 - val_iou_score: 0.7246
# Epoch 80/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7709 - accuracy: 0.9937 - iou_score: 0.8689 - val_loss: 0.8050 - val_accuracy: 0.9833 - val_iou_score: 0.7394
# Epoch 81/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7708 - accuracy: 0.9938 - iou_score: 0.8695 - val_loss: 0.8058 - val_accuracy: 0.9834 - val_iou_score: 0.7349
# Epoch 82/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7708 - accuracy: 0.9938 - iou_score: 0.8690 - val_loss: 0.8061 - val_accuracy: 0.9831 - val_iou_score: 0.7381
# Epoch 83/150
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7708 - accuracy: 0.9938 - iou_score: 0.8693 - val_loss: 0.8129 - val_accuracy: 0.9790 - val_iou_score: 0.7051
# Epoch 84/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7706 - accuracy: 0.9938 - iou_score: 0.8704 - val_loss: 0.8103 - val_accuracy: 0.9786 - val_iou_score: 0.7190
# Epoch 85/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7704 - accuracy: 0.9938 - iou_score: 0.8716 - val_loss: 0.8114 - val_accuracy: 0.9774 - val_iou_score: 0.7153
# Epoch 86/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7703 - accuracy: 0.9939 - iou_score: 0.8720 - val_loss: 0.8083 - val_accuracy: 0.9806 - val_iou_score: 0.7271
# Epoch 87/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7704 - accuracy: 0.9938 - iou_score: 0.8718 - val_loss: 0.8116 - val_accuracy: 0.9791 - val_iou_score: 0.7101
# Epoch 88/150
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7709 - accuracy: 0.9936 - iou_score: 0.8686 - val_loss: 0.8156 - val_accuracy: 0.9784 - val_iou_score: 0.6944
# Epoch 89/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7706 - accuracy: 0.9937 - iou_score: 0.8705 - val_loss: 0.8107 - val_accuracy: 0.9807 - val_iou_score: 0.7149
# Epoch 90/150
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7704 - accuracy: 0.9938 - iou_score: 0.8714 - val_loss: 0.8062 - val_accuracy: 0.9830 - val_iou_score: 0.7353
# Epoch 91/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7704 - accuracy: 0.9938 - iou_score: 0.8718 - val_loss: 0.8050 - val_accuracy: 0.9839 - val_iou_score: 0.7400
# Epoch 92/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7702 - accuracy: 0.9939 - iou_score: 0.8729 - val_loss: 0.8116 - val_accuracy: 0.9829 - val_iou_score: 0.7127
# Epoch 93/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7703 - accuracy: 0.9939 - iou_score: 0.8724 - val_loss: 0.8134 - val_accuracy: 0.9822 - val_iou_score: 0.7054
# Epoch 94/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7700 - accuracy: 0.9940 - iou_score: 0.8739 - val_loss: 0.8082 - val_accuracy: 0.9835 - val_iou_score: 0.7307
# Epoch 95/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7700 - accuracy: 0.9940 - iou_score: 0.8740 - val_loss: 0.8156 - val_accuracy: 0.9812 - val_iou_score: 0.7032
# Epoch 96/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7700 - accuracy: 0.9940 - iou_score: 0.8738 - val_loss: 0.8130 - val_accuracy: 0.9822 - val_iou_score: 0.7103
# Epoch 97/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7699 - accuracy: 0.9940 - iou_score: 0.8743 - val_loss: 0.8081 - val_accuracy: 0.9835 - val_iou_score: 0.7311
# Epoch 98/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7700 - accuracy: 0.9941 - iou_score: 0.8735 - val_loss: 0.8115 - val_accuracy: 0.9824 - val_iou_score: 0.7148
# Epoch 99/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7697 - accuracy: 0.9941 - iou_score: 0.8758 - val_loss: 0.8103 - val_accuracy: 0.9828 - val_iou_score: 0.7184
# Epoch 100/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7695 - accuracy: 0.9942 - iou_score: 0.8767 - val_loss: 0.8130 - val_accuracy: 0.9823 - val_iou_score: 0.7089
# Epoch 101/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7692 - accuracy: 0.9942 - iou_score: 0.8785 - val_loss: 0.8110 - val_accuracy: 0.9829 - val_iou_score: 0.7167
# Epoch 102/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7692 - accuracy: 0.9942 - iou_score: 0.8782 - val_loss: 0.8096 - val_accuracy: 0.9834 - val_iou_score: 0.7222
# Epoch 103/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7692 - accuracy: 0.9943 - iou_score: 0.8784 - val_loss: 0.8106 - val_accuracy: 0.9833 - val_iou_score: 0.7186
# Epoch 104/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7693 - accuracy: 0.9942 - iou_score: 0.8780 - val_loss: 0.8061 - val_accuracy: 0.9843 - val_iou_score: 0.7390
# Epoch 105/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7693 - accuracy: 0.9942 - iou_score: 0.8779 - val_loss: 0.8151 - val_accuracy: 0.9812 - val_iou_score: 0.7025
# Epoch 106/150
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7693 - accuracy: 0.9942 - iou_score: 0.8777 - val_loss: 0.8066 - val_accuracy: 0.9829 - val_iou_score: 0.7341
# Epoch 107/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7690 - accuracy: 0.9943 - iou_score: 0.8798 - val_loss: 0.8058 - val_accuracy: 0.9834 - val_iou_score: 0.7414
# Epoch 108/150
# 667/667 [==============================] - 86s 130ms/step - loss: 0.7689 - accuracy: 0.9943 - iou_score: 0.8802 - val_loss: 0.8052 - val_accuracy: 0.9835 - val_iou_score: 0.7418
# Epoch 109/150
# 667/667 [==============================] - 86s 130ms/step - loss: 0.7689 - accuracy: 0.9943 - iou_score: 0.8803 - val_loss: 0.8040 - val_accuracy: 0.9847 - val_iou_score: 0.7484
# Epoch 110/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7689 - accuracy: 0.9943 - iou_score: 0.8804 - val_loss: 0.8050 - val_accuracy: 0.9841 - val_iou_score: 0.7423
# Epoch 111/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7690 - accuracy: 0.9943 - iou_score: 0.8799 - val_loss: 0.8078 - val_accuracy: 0.9826 - val_iou_score: 0.7285
# Epoch 112/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7688 - accuracy: 0.9944 - iou_score: 0.8811 - val_loss: 0.8048 - val_accuracy: 0.9840 - val_iou_score: 0.7417
# Epoch 113/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7687 - accuracy: 0.9944 - iou_score: 0.8822 - val_loss: 0.8056 - val_accuracy: 0.9839 - val_iou_score: 0.7430
# Epoch 114/150
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7687 - accuracy: 0.9945 - iou_score: 0.8816 - val_loss: 0.8039 - val_accuracy: 0.9839 - val_iou_score: 0.7502
# Epoch 115/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7684 - accuracy: 0.9945 - iou_score: 0.8829 - val_loss: 0.8033 - val_accuracy: 0.9845 - val_iou_score: 0.7512
# Epoch 116/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7683 - accuracy: 0.9945 - iou_score: 0.8838 - val_loss: 0.8059 - val_accuracy: 0.9838 - val_iou_score: 0.7375
# Epoch 117/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7685 - accuracy: 0.9945 - iou_score: 0.8826 - val_loss: 0.8055 - val_accuracy: 0.9839 - val_iou_score: 0.7399
# Epoch 118/150
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7687 - accuracy: 0.9944 - iou_score: 0.8817 - val_loss: 0.8049 - val_accuracy: 0.9838 - val_iou_score: 0.7415
# Epoch 119/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7688 - accuracy: 0.9944 - iou_score: 0.8806 - val_loss: 0.8095 - val_accuracy: 0.9825 - val_iou_score: 0.7191
# Epoch 120/150
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7685 - accuracy: 0.9944 - iou_score: 0.8822 - val_loss: 0.8150 - val_accuracy: 0.9812 - val_iou_score: 0.6974
# Epoch 121/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7685 - accuracy: 0.9944 - iou_score: 0.8823 - val_loss: 0.8081 - val_accuracy: 0.9832 - val_iou_score: 0.7283
# Epoch 122/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7685 - accuracy: 0.9944 - iou_score: 0.8823 - val_loss: 0.8134 - val_accuracy: 0.9816 - val_iou_score: 0.7038
# Epoch 123/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7684 - accuracy: 0.9944 - iou_score: 0.8833 - val_loss: 0.8052 - val_accuracy: 0.9836 - val_iou_score: 0.7427
# Epoch 124/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7683 - accuracy: 0.9945 - iou_score: 0.8836 - val_loss: 0.8058 - val_accuracy: 0.9841 - val_iou_score: 0.7378
# Epoch 125/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7683 - accuracy: 0.9945 - iou_score: 0.8840 - val_loss: 0.8138 - val_accuracy: 0.9821 - val_iou_score: 0.7028
# Epoch 126/150
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7682 - accuracy: 0.9946 - iou_score: 0.8843 - val_loss: 0.8120 - val_accuracy: 0.9824 - val_iou_score: 0.7119
# Epoch 127/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7682 - accuracy: 0.9945 - iou_score: 0.8840 - val_loss: 0.8156 - val_accuracy: 0.9810 - val_iou_score: 0.6959
# Epoch 128/150
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7684 - accuracy: 0.9944 - iou_score: 0.8833 - val_loss: 0.8111 - val_accuracy: 0.9827 - val_iou_score: 0.7162
# Epoch 129/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7685 - accuracy: 0.9944 - iou_score: 0.8829 - val_loss: 0.8095 - val_accuracy: 0.9829 - val_iou_score: 0.7234
# Epoch 130/150
# 667/667 [==============================] - 84s 127ms/step - loss: 0.7681 - accuracy: 0.9945 - iou_score: 0.8850 - val_loss: 0.8095 - val_accuracy: 0.9829 - val_iou_score: 0.7204
# Epoch 131/150
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7683 - accuracy: 0.9945 - iou_score: 0.8838 - val_loss: 0.8110 - val_accuracy: 0.9822 - val_iou_score: 0.7139
# Epoch 132/150
# 667/667 [==============================] - 86s 130ms/step - loss: 0.7680 - accuracy: 0.9946 - iou_score: 0.8858 - val_loss: 0.8118 - val_accuracy: 0.9831 - val_iou_score: 0.7152
# Epoch 133/150
# 667/667 [==============================] - 84s 127ms/step - loss: 0.7677 - accuracy: 0.9947 - iou_score: 0.8876 - val_loss: 0.8145 - val_accuracy: 0.9830 - val_iou_score: 0.7049
# Epoch 134/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7678 - accuracy: 0.9946 - iou_score: 0.8865 - val_loss: 0.8023 - val_accuracy: 0.9850 - val_iou_score: 0.7534
# Epoch 135/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7678 - accuracy: 0.9946 - iou_score: 0.8865 - val_loss: 0.8066 - val_accuracy: 0.9839 - val_iou_score: 0.7420
# Epoch 136/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7677 - accuracy: 0.9947 - iou_score: 0.8870 - val_loss: 0.8131 - val_accuracy: 0.9833 - val_iou_score: 0.7175
# Epoch 137/150
# 667/667 [==============================] - 86s 130ms/step - loss: 0.7677 - accuracy: 0.9946 - iou_score: 0.8869 - val_loss: 0.8090 - val_accuracy: 0.9841 - val_iou_score: 0.7299
# Epoch 138/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7679 - accuracy: 0.9946 - iou_score: 0.8860 - val_loss: 0.8043 - val_accuracy: 0.9844 - val_iou_score: 0.7446
# Epoch 139/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7678 - accuracy: 0.9946 - iou_score: 0.8869 - val_loss: 0.8072 - val_accuracy: 0.9842 - val_iou_score: 0.7344
# Epoch 140/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7679 - accuracy: 0.9946 - iou_score: 0.8860 - val_loss: 0.8048 - val_accuracy: 0.9849 - val_iou_score: 0.7401
# Epoch 141/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7678 - accuracy: 0.9946 - iou_score: 0.8868 - val_loss: 0.8081 - val_accuracy: 0.9846 - val_iou_score: 0.7372
# Epoch 142/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7677 - accuracy: 0.9946 - iou_score: 0.8872 - val_loss: 0.8068 - val_accuracy: 0.9843 - val_iou_score: 0.7409
# Epoch 143/150
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7675 - accuracy: 0.9947 - iou_score: 0.8884 - val_loss: 0.8049 - val_accuracy: 0.9847 - val_iou_score: 0.7414
# Epoch 144/150
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7674 - accuracy: 0.9948 - iou_score: 0.8893 - val_loss: 0.7997 - val_accuracy: 0.9856 - val_iou_score: 0.7645
# Epoch 145/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7673 - accuracy: 0.9948 - iou_score: 0.8894 - val_loss: 0.8052 - val_accuracy: 0.9851 - val_iou_score: 0.7519
# Epoch 146/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7674 - accuracy: 0.9948 - iou_score: 0.8889 - val_loss: 0.8081 - val_accuracy: 0.9846 - val_iou_score: 0.7409
# Epoch 147/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7674 - accuracy: 0.9948 - iou_score: 0.8889 - val_loss: 0.8083 - val_accuracy: 0.9828 - val_iou_score: 0.7322
# Epoch 148/150
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7674 - accuracy: 0.9948 - iou_score: 0.8891 - val_loss: 0.8012 - val_accuracy: 0.9846 - val_iou_score: 0.7614
# Epoch 149/150
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7675 - accuracy: 0.9947 - iou_score: 0.8883 - val_loss: 0.8010 - val_accuracy: 0.9841 - val_iou_score: 0.7588
# Epoch 150/150
# 667/667 [==============================] - 87s 131ms/step - loss: 0.7673 - accuracy: 0.9948 - iou_score: 0.8896 - val_loss: 0.7993 - val_accuracy: 0.9850 - val_iou_score: 0.7681

# %%
#plot the training and validation IoU and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from keras.models import load_model

#Load model for prediction or continue training

#For continuing training....
#The following gives an error: Unknown loss function: dice_loss_plus_1focal_loss
#This is because the model does not save loss function and metrics. So to compile and 
#continue training we need to provide these as custom_objects.

# my_model = load_model('saved_models/brats_3d_100epochs_simple_unet_weighted_dice.hdf5')

#So let us add the loss as custom object... but the following throws another error...
#Unknown metric function: iou_score

# my_model = load_model('saved_models/brats_3d_100epochs_simple_unet_weighted_dice.hdf5', 
#                       custom_objects={'dice_loss_plus_1focal_loss': total_loss})

#Now, let us add the iou_score function we used during our initial training
my_model = load_model('brats_2020_2021_3d_first.hdf5', 
                      custom_objects={'dice_loss_plus_1focal_loss': total_loss,
                                      'iou_score':sm.metrics.IOUScore(threshold=0.5)})

#Now all set to continue the training process. 
history2=my_model.fit(train_img_datagen,
          steps_per_epoch=steps_per_epoch,
          epochs=1,
          verbose=1,
          validation_data=val_img_datagen,
          validation_steps=val_steps_per_epoch,
          )
# Out:
# 2025-04-22 19:30:43.964634: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 667/667 [==============================] - ETA: 0s - loss: 0.7672 - accuracy: 0.9948 - iou_score: 0.8900
# 2025-04-22 19:32:03.073542: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 667/667 [==============================] - 87s 129ms/step - loss: 0.7672 - accuracy: 0.9948 - iou_score: 0.8900 - val_loss: 0.8056 - val_accuracy: 0.9833 - val_iou_score: 0.7484

# %%
my_model = load_model('brats_2020_2021_3d_first.hdf5', 
                      compile=False)


#Verify IoU on a batch of images from the test dataset
#Using built in keras function for IoU
#Only works on TF > 2.0
from keras.metrics import MeanIoU

batch_size=8 #Check IoU for a batch of images
test_img_datagen = imageLoader(val_img_dir, val_img_list, 
                                val_mask_dir, val_mask_list, batch_size)

#Verify generator.... In python 3 next() is renamed as __next__()
test_image_batch, test_mask_batch = test_img_datagen.__next__()

test_mask_batch_argmax = np.argmax(test_mask_batch, axis=4)
test_pred_batch = my_model.predict(test_image_batch)
test_pred_batch_argmax = np.argmax(test_pred_batch, axis=4)

n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(test_pred_batch_argmax, test_mask_batch_argmax)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# 1/1 [==============================] - 5s 5s/step
# Mean IoU = 0.85609186

# %%
#Predict on a few test images, one at a time
#Try images: 
from keras.models import load_model 

my_model = load_model('brats_2020_2021_3d_first.hdf5', compile=False) 

import numpy as np 

# img_num = 57
# img_num = 143
# img_num = 165 never 
img_num = 77

test_img = np.load("2020_2021_Validation/images/image_"+str(img_num)+".npy")

test_mask = np.load("2020_2021_Validation/masks/mask_"+str(img_num)+".npy")
test_mask_argmax=np.argmax(test_mask, axis=3)

test_img_input = np.expand_dims(test_img, axis=0)
test_prediction = my_model.predict(test_img_input)
test_prediction_argmax=np.argmax(test_prediction, axis=4)[0,:,:,:]


# print(test_prediction_argmax.shape)
# print(test_mask_argmax.shape)
# print(np.unique(test_prediction_argmax))


#Plot individual slices from test predictions for verification
from matplotlib import pyplot as plt
import random

#n_slice=random.randint(0, test_prediction_argmax.shape[2])
n_slice = 55
plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,n_slice,1], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_argmax[:,:,n_slice])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction_argmax[:,:, n_slice])
plt.show()
# Out:
# 1/1 [==============================] - 0s 162ms/step
