# %%
#from tifffile import imsave, imread
import os
import numpy as np

def load_img(img_dir, img_list):
    images=[]
    for i, image_name in enumerate(img_list):    
        if (image_name.split('.')[1] == 'npy'):
            
            image = np.load(img_dir+image_name)
                      
            images.append(image)
    images = np.array(images)
    
    return(images)

def imageLoader(img_dir, img_list, mask_dir, mask_list, batch_size):

    L = len(img_list)

    #keras needs the generator infinite, so we will use while true  
    while True:

        batch_start = 0
        batch_end = batch_size

        while batch_start < L:
            limit = min(batch_end, L)
                       
            X = load_img(img_dir, img_list[batch_start:limit])
            Y = load_img(mask_dir, mask_list[batch_start:limit])

            yield (X,Y) #a tuple with two numpy arrays with batch_size samples     

            batch_start += batch_size   
            batch_end += batch_size

# %%
import os
import numpy as np
# from custom_datagen import ImageLoader
import tensorflow as tf
import keras
from matplotlib import pyplot as plt
import glob
import random
# Out:
# 2025-03-31 18:56:32.471036: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-31 18:56:32.508040: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_img_dir = "2020_2021_Dataset/images/"
train_mask_dir = "2020_2021_Dataset/masks/"

img_list = os.listdir(train_img_dir)
msk_list = os.listdir(train_mask_dir)

num_images = len(os.listdir(train_img_dir))

img_num = random.randint(0,num_images-1)
test_img = np.load(train_img_dir+img_list[img_num])
test_mask = np.load(train_mask_dir+msk_list[img_num])
test_mask = np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
import pandas as pd
columns = ['0','1', '2', '3']
df = pd.DataFrame(columns=columns)
train_mask_list = sorted(glob.glob('2020_2021_Dataset/masks/*.npy'))
for img in range(len(train_mask_list)):
    print(img)
    temp_image=np.load(train_mask_list[img])
    temp_image = np.argmax(temp_image, axis=3)
    val, counts = np.unique(temp_image, return_counts=True)
    zipped = zip(columns, counts)
    conts_dict = dict(zipped)
    
    df = df.append(conts_dict, ignore_index=True)

label_0 = df['0'].sum()
label_1 = df['1'].sum()
label_2 = df['1'].sum()
label_3 = df['3'].sum()
total_labels = label_0 + label_1 + label_2 + label_3
n_classes = 4
#Class weights claculation: n_samples / (n_classes * n_samples_for_class)
wt0 = round((total_labels/(n_classes*label_0)), 2) #round to 2 decimals
wt1 = round((total_labels/(n_classes*label_1)), 2)
wt2 = round((total_labels/(n_classes*label_2)), 2)
wt3 = round((total_labels/(n_classes*label_3)), 2)

#Weights are: 0.26, 22.53, 22.53, 26.21
#wt0, wt1, wt2, wt3 = 0.26, 22.53, 22.53, 26.21
#These weihts can be used for Dice loss
# Out:
# 0
# /tmp/ipykernel_1402/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1
# /tmp/ipykernel_1402/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 2
# /tmp/ipykernel_1402/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 3
# /tmp/ipykernel_1402/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 4
# /tmp/ipykernel_1402/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_1402/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 5
# 6
# /tmp/ipykernel_1402/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 7
# /tmp/ipykernel_1402/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 8
# /tmp/ipykernel_1402/1122951101.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/.ipython/Train_brats2020_V5.ipynb Cell 4 line 7
#       <a href='vscode-notebook-cell://884ca62860890.notebooks.jarvislabs.net/home/.ipython/Train_brats2020_V5.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> for img in range(len(train_mask_list)):
#       <a href='vscode-notebook-cell://884ca62860890.notebooks.jarvislabs.net/home/.ipython/Train_brats2020_V5.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     print(img)
# ----> <a href='vscode-notebook-cell://884ca62860890.notebooks.jarvislabs.net/home/.ipython/Train_brats2020_V5.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     temp_image=np.load(train_mask_list[img])
#       <a href='vscode-notebook-cell://884ca62860890.notebooks.jarvislabs.net/home/.ipython/Train_brats2020_V5.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     temp_image = np.argmax(temp_image, axis=3)
#       <a href='vscode-notebook-cell://884ca62860890.notebooks.jarvislabs.net/home/.ipython/Train_brats2020_V5.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>     val, counts = np.unique(temp_image, return_counts=True)
#
# File /usr/local/lib/python3.8/dist-packages/numpy/lib/npyio.py:432, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     429         return format.open_memmap(file, mode=mmap_mode,
#     430                                   max_header_size=max_header_size)
#     431     else:
# --> 432         return format.read_array(fid, allow_pickle=allow_pickle,
#     433                                  pickle_kwargs=pickle_kwargs,
#     434                                  max_header_size=max_header_size)
#     435 else:
#     436     # Try a pickle
#     437     if not allow_pickle:
#
# File /usr/local/lib/python3.8/dist-packages/numpy/lib/format.py:790, in read_array(fp, allow_pickle, pickle_kwargs, max_header_size)
#     787 else:
#     788     if isfileobj(fp):
#     789         # We can use the fast fromfile() function.
# --> 790         array = numpy.fromfile(fp, dtype=dtype, count=count)
#     791     else:
#     792         # This is not a real file. We have to read it the
#     793         # memory-intensive way.
#    (...)
#     801         # not correctly instantiate zero-width string dtypes; see
#     802         # https://github.com/numpy/numpy/pull/6430
#     803         array = numpy.ndarray(count, dtype=dtype)
#
# KeyboardInterrupt:

# %%
#Define the image generators for training and validation

train_img_dir = "2020_2021_Dataset/images/"
train_mask_dir = "2020_2021_Dataset/masks/"

val_img_dir = "2020_2021_Validation/images/"
val_mask_dir = "2020_2021_Validation/masks/"

train_img_list=os.listdir(train_img_dir)
train_mask_list = os.listdir(train_mask_dir)

val_img_list=os.listdir(val_img_dir)
val_mask_list = os.listdir(val_mask_dir)

# %%
batch_size = 2

train_img_datagen = imageLoader(train_img_dir, train_img_list, 
                                train_mask_dir, train_mask_list, batch_size)

val_img_datagen = imageLoader(val_img_dir, val_img_list, 
                                val_mask_dir, val_mask_list, batch_size)

#Verify generator.... In python 3 next() is renamed as __next__()
img, msk = train_img_datagen.__next__()

img_num = random.randint(0,img.shape[0]-1)
test_img=img[img_num]
test_mask=msk[img_num]
test_mask=np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
import tensorflow as tf
print(tf.__version__)
import keras
print(keras.__version__)
# Out:
# 2.12.0
# 2.12.0

# %%
#Define loss, metrics and optimizer to be used for training
wt0, wt1, wt2, wt3 = 0.25,0.25,0.25,0.25
import segmentation_models_3D as sm
dice_loss = sm.losses.DiceLoss(class_weights=np.array([wt0, wt1, wt2, wt3])) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

metrics = ['accuracy', sm.metrics.IOUScore(threshold=0.5)]

LR = 0.0001
optim = keras.optimizers.Adam(LR)
# Out:
# Segmentation Models: using `keras` framework.

# %%
from keras.models import Model
from keras.layers import Input, Conv3D, MaxPooling3D, concatenate, Conv3DTranspose, BatchNormalization, Dropout, Lambda
from keras.optimizers import Adam
from keras.metrics import MeanIoU

kernel_initializer =  'he_uniform' #Try others if you want

def simple_unet_model(IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS, num_classes):
#Build the model
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(s)
    c1 = Dropout(0.1)(c1)
    c1 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c1)
    p1 = MaxPooling3D((2, 2, 2))(c1)
    
    c2 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c2)
    p2 = MaxPooling3D((2, 2, 2))(c2)
     
    c3 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c3)
    p3 = MaxPooling3D((2, 2, 2))(c3)
     
    c4 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c4)
    p4 = MaxPooling3D(pool_size=(2, 2, 2))(c4)
     
    c5 = Conv3D(256, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv3D(256, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c5)
    
    #Expansive path 
    u6 = Conv3DTranspose(128, (2, 2, 2), strides=(2, 2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c6)
     
    u7 = Conv3DTranspose(64, (2, 2, 2), strides=(2, 2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c7)
     
    u8 = Conv3DTranspose(32, (2, 2, 2), strides=(2, 2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c8)
     
    u9 = Conv3DTranspose(16, (2, 2, 2), strides=(2, 2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1])
    c9 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c9)
     
    outputs = Conv3D(num_classes, (1, 1, 1), activation='softmax')(c9)
     
    model = Model(inputs=[inputs], outputs=[outputs])
    #compile model outside of this function to make it flexible. 
    model.summary()
    
    return model

# %%
#Fit the model 

steps_per_epoch = len(train_img_list)//batch_size
val_steps_per_epoch = len(val_img_list)//batch_size


# from simple_3d_unet import simple_unet_model

model = simple_unet_model(IMG_HEIGHT=128, 
                          IMG_WIDTH=128, 
                          IMG_DEPTH=128, 
                          IMG_CHANNELS=3, 
                          num_classes=4)

model.compile(optimizer = optim, loss=total_loss, metrics=metrics)
print(model.summary())

print(model.input_shape)
print(model.output_shape)

history=model.fit(train_img_datagen,
          steps_per_epoch=steps_per_epoch,
          epochs=100,
          verbose=1,
          validation_data=val_img_datagen,
          validation_steps=val_steps_per_epoch,
          )

model.save('brats_2020_2021_3d_first.hdf5')
# Out:
# 2025-03-31 18:57:13.809977: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46551 MB memory:  -> device: 0, name: NVIDIA RTX 6000 Ada Generation, pci bus id: 0000:41:00.0, compute capability: 8.9
# 2025-03-31 18:57:13.811517: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46551 MB memory:  -> device: 1, name: NVIDIA RTX 6000 Ada Generation, pci bus id: 0000:61:00.0, compute capability: 8.9
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 28, 3)]
#
#  conv3d (Conv3D)                (None, 128, 128, 12  1312        ['input_1[0][0]']
#                                 8, 16)
#
#  dropout (Dropout)              (None, 128, 128, 12  0           ['conv3d[0][0]']
#                                 8, 16)
#
#  conv3d_1 (Conv3D)              (None, 128, 128, 12  6928        ['dropout[0][0]']
#                                 8, 16)
#
#  max_pooling3d (MaxPooling3D)   (None, 64, 64, 64,   0           ['conv3d_1[0][0]']
#                                 16)
#
#  conv3d_2 (Conv3D)              (None, 64, 64, 64,   13856       ['max_pooling3d[0][0]']
#                                 32)
#
#  dropout_1 (Dropout)            (None, 64, 64, 64,   0           ['conv3d_2[0][0]']
#                                 32)
#
#  conv3d_3 (Conv3D)              (None, 64, 64, 64,   27680       ['dropout_1[0][0]']
#                                 32)
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 32, 32, 32,   0          ['conv3d_3[0][0]']
#                                 32)
#
#  conv3d_4 (Conv3D)              (None, 32, 32, 32,   55360       ['max_pooling3d_1[0][0]']
#                                 64)
#
#  dropout_2 (Dropout)            (None, 32, 32, 32,   0           ['conv3d_4[0][0]']
#                                 64)
#
#  conv3d_5 (Conv3D)              (None, 32, 32, 32,   110656      ['dropout_2[0][0]']
#                                 64)
#
#  max_pooling3d_2 (MaxPooling3D)  (None, 16, 16, 16,   0          ['conv3d_5[0][0]']
#                                 64)
#
#  conv3d_6 (Conv3D)              (None, 16, 16, 16,   221312      ['max_pooling3d_2[0][0]']
#                                 128)
#
#  dropout_3 (Dropout)            (None, 16, 16, 16,   0           ['conv3d_6[0][0]']
#                                 128)
#
#  conv3d_7 (Conv3D)              (None, 16, 16, 16,   442496      ['dropout_3[0][0]']
#                                 128)
#
#  max_pooling3d_3 (MaxPooling3D)  (None, 8, 8, 8, 128  0          ['conv3d_7[0][0]']
#                                 )
#
#  conv3d_8 (Conv3D)              (None, 8, 8, 8, 256  884992      ['max_pooling3d_3[0][0]']
#                                 )
#
#  dropout_4 (Dropout)            (None, 8, 8, 8, 256  0           ['conv3d_8[0][0]']
#                                 )
#
#  conv3d_9 (Conv3D)              (None, 8, 8, 8, 256  1769728     ['dropout_4[0][0]']
#                                 )
#
#  conv3d_transpose (Conv3DTransp  (None, 16, 16, 16,   262272     ['conv3d_9[0][0]']
#  ose)                           128)
#
#  concatenate (Concatenate)      (None, 16, 16, 16,   0           ['conv3d_transpose[0][0]',
#                                 256)                              'conv3d_7[0][0]']
#
#  conv3d_10 (Conv3D)             (None, 16, 16, 16,   884864      ['concatenate[0][0]']
#                                 128)
#
#  dropout_5 (Dropout)            (None, 16, 16, 16,   0           ['conv3d_10[0][0]']
#                                 128)
#
#  conv3d_11 (Conv3D)             (None, 16, 16, 16,   442496      ['dropout_5[0][0]']
#                                 128)
#
#  conv3d_transpose_1 (Conv3DTran  (None, 32, 32, 32,   65600      ['conv3d_11[0][0]']
#  spose)                         64)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_1[0][0]',
#                                 128)                              'conv3d_5[0][0]']
#
#  conv3d_12 (Conv3D)             (None, 32, 32, 32,   221248      ['concatenate_1[0][0]']
#                                 64)
#
#  dropout_6 (Dropout)            (None, 32, 32, 32,   0           ['conv3d_12[0][0]']
#                                 64)
#
#  conv3d_13 (Conv3D)             (None, 32, 32, 32,   110656      ['dropout_6[0][0]']
#                                 64)
#
#  conv3d_transpose_2 (Conv3DTran  (None, 64, 64, 64,   16416      ['conv3d_13[0][0]']
#  spose)                         32)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64,   0           ['conv3d_transpose_2[0][0]',
#                                 64)                               'conv3d_3[0][0]']
#
#  conv3d_14 (Conv3D)             (None, 64, 64, 64,   55328       ['concatenate_2[0][0]']
#                                 32)
#
#  dropout_7 (Dropout)            (None, 64, 64, 64,   0           ['conv3d_14[0][0]']
#                                 32)
#
#  conv3d_15 (Conv3D)             (None, 64, 64, 64,   27680       ['dropout_7[0][0]']
#                                 32)
#
#  conv3d_transpose_3 (Conv3DTran  (None, 128, 128, 12  4112       ['conv3d_15[0][0]']
#  spose)                         8, 16)
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 12  0           ['conv3d_transpose_3[0][0]',
#                                 8, 32)                            'conv3d_1[0][0]']
#
#  conv3d_16 (Conv3D)             (None, 128, 128, 12  13840       ['concatenate_3[0][0]']
#                                 8, 16)
#
#  dropout_8 (Dropout)            (None, 128, 128, 12  0           ['conv3d_16[0][0]']
#                                 8, 16)
#
#  conv3d_17 (Conv3D)             (None, 128, 128, 12  6928        ['dropout_8[0][0]']
#                                 8, 16)
#
#  conv3d_18 (Conv3D)             (None, 128, 128, 12  68          ['conv3d_17[0][0]']
#                                 8, 4)
#
# ==================================================================================================
# Total params: 5,645,828
# Trainable params: 5,645,828
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 28, 3)]
#
#  conv3d (Conv3D)                (None, 128, 128, 12  1312        ['input_1[0][0]']
#                                 8, 16)
#
#  dropout (Dropout)              (None, 128, 128, 12  0           ['conv3d[0][0]']
#                                 8, 16)
#
#  conv3d_1 (Conv3D)              (None, 128, 128, 12  6928        ['dropout[0][0]']
#                                 8, 16)
#
#  max_pooling3d (MaxPooling3D)   (None, 64, 64, 64,   0           ['conv3d_1[0][0]']
#                                 16)
#
#  conv3d_2 (Conv3D)              (None, 64, 64, 64,   13856       ['max_pooling3d[0][0]']
#                                 32)
#
#  dropout_1 (Dropout)            (None, 64, 64, 64,   0           ['conv3d_2[0][0]']
#                                 32)
#
#  conv3d_3 (Conv3D)              (None, 64, 64, 64,   27680       ['dropout_1[0][0]']
#                                 32)
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 32, 32, 32,   0          ['conv3d_3[0][0]']
#                                 32)
#
#  conv3d_4 (Conv3D)              (None, 32, 32, 32,   55360       ['max_pooling3d_1[0][0]']
#                                 64)
#
#  dropout_2 (Dropout)            (None, 32, 32, 32,   0           ['conv3d_4[0][0]']
#                                 64)
#
#  conv3d_5 (Conv3D)              (None, 32, 32, 32,   110656      ['dropout_2[0][0]']
#                                 64)
#
#  max_pooling3d_2 (MaxPooling3D)  (None, 16, 16, 16,   0          ['conv3d_5[0][0]']
#                                 64)
#
#  conv3d_6 (Conv3D)              (None, 16, 16, 16,   221312      ['max_pooling3d_2[0][0]']
#                                 128)
#
#  dropout_3 (Dropout)            (None, 16, 16, 16,   0           ['conv3d_6[0][0]']
#                                 128)
#
#  conv3d_7 (Conv3D)              (None, 16, 16, 16,   442496      ['dropout_3[0][0]']
#                                 128)
#
#  max_pooling3d_3 (MaxPooling3D)  (None, 8, 8, 8, 128  0          ['conv3d_7[0][0]']
#                                 )
#
#  conv3d_8 (Conv3D)              (None, 8, 8, 8, 256  884992      ['max_pooling3d_3[0][0]']
#                                 )
#
#  dropout_4 (Dropout)            (None, 8, 8, 8, 256  0           ['conv3d_8[0][0]']
#                                 )
#
#  conv3d_9 (Conv3D)              (None, 8, 8, 8, 256  1769728     ['dropout_4[0][0]']
#                                 )
#
#  conv3d_transpose (Conv3DTransp  (None, 16, 16, 16,   262272     ['conv3d_9[0][0]']
#  ose)                           128)
#
#  concatenate (Concatenate)      (None, 16, 16, 16,   0           ['conv3d_transpose[0][0]',
#                                 256)                              'conv3d_7[0][0]']
#
#  conv3d_10 (Conv3D)             (None, 16, 16, 16,   884864      ['concatenate[0][0]']
#                                 128)
#
#  dropout_5 (Dropout)            (None, 16, 16, 16,   0           ['conv3d_10[0][0]']
#                                 128)
#
#  conv3d_11 (Conv3D)             (None, 16, 16, 16,   442496      ['dropout_5[0][0]']
#                                 128)
#
#  conv3d_transpose_1 (Conv3DTran  (None, 32, 32, 32,   65600      ['conv3d_11[0][0]']
#  spose)                         64)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_1[0][0]',
#                                 128)                              'conv3d_5[0][0]']
#
#  conv3d_12 (Conv3D)             (None, 32, 32, 32,   221248      ['concatenate_1[0][0]']
#                                 64)
#
#  dropout_6 (Dropout)            (None, 32, 32, 32,   0           ['conv3d_12[0][0]']
#                                 64)
#
#  conv3d_13 (Conv3D)             (None, 32, 32, 32,   110656      ['dropout_6[0][0]']
#                                 64)
#
#  conv3d_transpose_2 (Conv3DTran  (None, 64, 64, 64,   16416      ['conv3d_13[0][0]']
#  spose)                         32)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64,   0           ['conv3d_transpose_2[0][0]',
#                                 64)                               'conv3d_3[0][0]']
#
#  conv3d_14 (Conv3D)             (None, 64, 64, 64,   55328       ['concatenate_2[0][0]']
#                                 32)
#
#  dropout_7 (Dropout)            (None, 64, 64, 64,   0           ['conv3d_14[0][0]']
#                                 32)
#
#  conv3d_15 (Conv3D)             (None, 64, 64, 64,   27680       ['dropout_7[0][0]']
#                                 32)
#
#  conv3d_transpose_3 (Conv3DTran  (None, 128, 128, 12  4112       ['conv3d_15[0][0]']
#  spose)                         8, 16)
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 12  0           ['conv3d_transpose_3[0][0]',
#                                 8, 32)                            'conv3d_1[0][0]']
#
#  conv3d_16 (Conv3D)             (None, 128, 128, 12  13840       ['concatenate_3[0][0]']
#                                 8, 16)
#
#  dropout_8 (Dropout)            (None, 128, 128, 12  0           ['conv3d_16[0][0]']
#                                 8, 16)
#
#  conv3d_17 (Conv3D)             (None, 128, 128, 12  6928        ['dropout_8[0][0]']
#                                 8, 16)
#
#  conv3d_18 (Conv3D)             (None, 128, 128, 12  68          ['conv3d_17[0][0]']
#                                 8, 4)
#
# ==================================================================================================
# Total params: 5,645,828
# Trainable params: 5,645,828
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# (None, 128, 128, 128, 3)
# (None, 128, 128, 128, 4)
# Epoch 1/100
# 2025-03-31 18:57:16.992432: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2025-03-31 18:57:18.598009: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8700
# 691/691 [==============================] - ETA: 0s - loss: 0.9067 - accuracy: 0.9462 - iou_score: 0.3522
# 2025-03-31 19:20:06.999473: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 691/691 [==============================] - 1497s 2s/step - loss: 0.9067 - accuracy: 0.9462 - iou_score: 0.3522 - val_loss: 0.9087 - val_accuracy: 0.9367 - val_iou_score: 0.3702
# Epoch 2/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.8653 - accuracy: 0.9673 - iou_score: 0.4902 - val_loss: 0.8994 - val_accuracy: 0.9452 - val_iou_score: 0.4026
# Epoch 3/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.8489 - accuracy: 0.9718 - iou_score: 0.5476 - val_loss: 0.8998 - val_accuracy: 0.9352 - val_iou_score: 0.4078
# Epoch 4/100
# 691/691 [==============================] - 87s 126ms/step - loss: 0.8314 - accuracy: 0.9745 - iou_score: 0.6125 - val_loss: 0.8807 - val_accuracy: 0.9498 - val_iou_score: 0.4614
# Epoch 5/100
# 691/691 [==============================] - 87s 126ms/step - loss: 0.8215 - accuracy: 0.9774 - iou_score: 0.6494 - val_loss: 0.8761 - val_accuracy: 0.9497 - val_iou_score: 0.4765
# Epoch 6/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.8172 - accuracy: 0.9788 - iou_score: 0.6659 - val_loss: 0.8760 - val_accuracy: 0.9496 - val_iou_score: 0.4751
# Epoch 7/100
# 691/691 [==============================] - 87s 126ms/step - loss: 0.8136 - accuracy: 0.9798 - iou_score: 0.6816 - val_loss: 0.8711 - val_accuracy: 0.9519 - val_iou_score: 0.4916
# Epoch 8/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.8111 - accuracy: 0.9807 - iou_score: 0.6924 - val_loss: 0.8661 - val_accuracy: 0.9574 - val_iou_score: 0.5091
# Epoch 9/100
# 691/691 [==============================] - 87s 126ms/step - loss: 0.8089 - accuracy: 0.9811 - iou_score: 0.7011 - val_loss: 0.8639 - val_accuracy: 0.9557 - val_iou_score: 0.5177
# Epoch 10/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.8069 - accuracy: 0.9818 - iou_score: 0.7096 - val_loss: 0.8659 - val_accuracy: 0.9568 - val_iou_score: 0.5118
# Epoch 11/100
# 691/691 [==============================] - 87s 126ms/step - loss: 0.8048 - accuracy: 0.9826 - iou_score: 0.7183 - val_loss: 0.8599 - val_accuracy: 0.9612 - val_iou_score: 0.5326
# Epoch 12/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.8041 - accuracy: 0.9821 - iou_score: 0.7221 - val_loss: 0.8570 - val_accuracy: 0.9604 - val_iou_score: 0.5411
# Epoch 13/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.8016 - accuracy: 0.9835 - iou_score: 0.7327 - val_loss: 0.8505 - val_accuracy: 0.9662 - val_iou_score: 0.5650
# Epoch 14/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.8004 - accuracy: 0.9839 - iou_score: 0.7391 - val_loss: 0.8576 - val_accuracy: 0.9627 - val_iou_score: 0.5424
# Epoch 15/100
# 691/691 [==============================] - 87s 126ms/step - loss: 0.7997 - accuracy: 0.9841 - iou_score: 0.7416 - val_loss: 0.8561 - val_accuracy: 0.9603 - val_iou_score: 0.5458
# Epoch 16/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7977 - accuracy: 0.9846 - iou_score: 0.7507 - val_loss: 0.8515 - val_accuracy: 0.9650 - val_iou_score: 0.5614
# Epoch 17/100
# 691/691 [==============================] - 86s 124ms/step - loss: 0.7968 - accuracy: 0.9849 - iou_score: 0.7552 - val_loss: 0.8524 - val_accuracy: 0.9631 - val_iou_score: 0.5604
# Epoch 18/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7964 - accuracy: 0.9850 - iou_score: 0.7576 - val_loss: 0.8500 - val_accuracy: 0.9673 - val_iou_score: 0.5692
# Epoch 19/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7950 - accuracy: 0.9853 - iou_score: 0.7630 - val_loss: 0.8483 - val_accuracy: 0.9645 - val_iou_score: 0.5744
# Epoch 20/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7942 - accuracy: 0.9856 - iou_score: 0.7670 - val_loss: 0.8470 - val_accuracy: 0.9675 - val_iou_score: 0.5795
# Epoch 21/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.7931 - accuracy: 0.9860 - iou_score: 0.7720 - val_loss: 0.8497 - val_accuracy: 0.9639 - val_iou_score: 0.5717
# Epoch 22/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7927 - accuracy: 0.9859 - iou_score: 0.7739 - val_loss: 0.8429 - val_accuracy: 0.9696 - val_iou_score: 0.5943
# Epoch 23/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7924 - accuracy: 0.9862 - iou_score: 0.7757 - val_loss: 0.8446 - val_accuracy: 0.9659 - val_iou_score: 0.5882
# Epoch 24/100
# 691/691 [==============================] - 87s 126ms/step - loss: 0.7914 - accuracy: 0.9865 - iou_score: 0.7798 - val_loss: 0.8475 - val_accuracy: 0.9670 - val_iou_score: 0.5802
# Epoch 25/100
# 691/691 [==============================] - 86s 124ms/step - loss: 0.7909 - accuracy: 0.9868 - iou_score: 0.7825 - val_loss: 0.8434 - val_accuracy: 0.9688 - val_iou_score: 0.5969
# Epoch 26/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7900 - accuracy: 0.9870 - iou_score: 0.7866 - val_loss: 0.8430 - val_accuracy: 0.9697 - val_iou_score: 0.5915
# Epoch 27/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.7902 - accuracy: 0.9867 - iou_score: 0.7852 - val_loss: 0.8454 - val_accuracy: 0.9678 - val_iou_score: 0.5895
# Epoch 28/100
# 691/691 [==============================] - 87s 126ms/step - loss: 0.7898 - accuracy: 0.9869 - iou_score: 0.7871 - val_loss: 0.8396 - val_accuracy: 0.9711 - val_iou_score: 0.6095
# Epoch 29/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.7886 - accuracy: 0.9874 - iou_score: 0.7931 - val_loss: 0.8392 - val_accuracy: 0.9703 - val_iou_score: 0.6098
# Epoch 30/100
# 691/691 [==============================] - 87s 126ms/step - loss: 0.7881 - accuracy: 0.9876 - iou_score: 0.7951 - val_loss: 0.8392 - val_accuracy: 0.9717 - val_iou_score: 0.6136
# Epoch 31/100
# 691/691 [==============================] - 87s 126ms/step - loss: 0.7877 - accuracy: 0.9876 - iou_score: 0.7969 - val_loss: 0.8376 - val_accuracy: 0.9704 - val_iou_score: 0.6180
# Epoch 32/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.7871 - accuracy: 0.9878 - iou_score: 0.7997 - val_loss: 0.8369 - val_accuracy: 0.9722 - val_iou_score: 0.6215
# Epoch 33/100
# 691/691 [==============================] - 87s 126ms/step - loss: 0.7865 - accuracy: 0.9879 - iou_score: 0.8022 - val_loss: 0.8362 - val_accuracy: 0.9724 - val_iou_score: 0.6234
# Epoch 34/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7864 - accuracy: 0.9881 - iou_score: 0.8021 - val_loss: 0.8356 - val_accuracy: 0.9726 - val_iou_score: 0.6261
# Epoch 35/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.7862 - accuracy: 0.9881 - iou_score: 0.8034 - val_loss: 0.8358 - val_accuracy: 0.9726 - val_iou_score: 0.6228
# Epoch 36/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.7856 - accuracy: 0.9884 - iou_score: 0.8061 - val_loss: 0.8324 - val_accuracy: 0.9737 - val_iou_score: 0.6366
# Epoch 37/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.7868 - accuracy: 0.9877 - iou_score: 0.8019 - val_loss: 0.8421 - val_accuracy: 0.9708 - val_iou_score: 0.6027
# Epoch 38/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7852 - accuracy: 0.9885 - iou_score: 0.8083 - val_loss: 0.8309 - val_accuracy: 0.9734 - val_iou_score: 0.6425
# Epoch 39/100
# 691/691 [==============================] - 86s 124ms/step - loss: 0.7844 - accuracy: 0.9888 - iou_score: 0.8118 - val_loss: 0.8345 - val_accuracy: 0.9729 - val_iou_score: 0.6298
# Epoch 40/100
# 691/691 [==============================] - 85s 122ms/step - loss: 0.7843 - accuracy: 0.9887 - iou_score: 0.8120 - val_loss: 0.8307 - val_accuracy: 0.9739 - val_iou_score: 0.6434
# Epoch 41/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7840 - accuracy: 0.9890 - iou_score: 0.8132 - val_loss: 0.8349 - val_accuracy: 0.9713 - val_iou_score: 0.6275
# Epoch 42/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7838 - accuracy: 0.9888 - iou_score: 0.8151 - val_loss: 0.8294 - val_accuracy: 0.9740 - val_iou_score: 0.6481
# Epoch 43/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7836 - accuracy: 0.9890 - iou_score: 0.8156 - val_loss: 0.8295 - val_accuracy: 0.9728 - val_iou_score: 0.6456
# Epoch 44/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7839 - accuracy: 0.9889 - iou_score: 0.8135 - val_loss: 0.8335 - val_accuracy: 0.9704 - val_iou_score: 0.6322
# Epoch 45/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7833 - accuracy: 0.9890 - iou_score: 0.8162 - val_loss: 0.8323 - val_accuracy: 0.9709 - val_iou_score: 0.6362
# Epoch 46/100
# 691/691 [==============================] - 86s 124ms/step - loss: 0.7833 - accuracy: 0.9892 - iou_score: 0.8171 - val_loss: 0.8354 - val_accuracy: 0.9712 - val_iou_score: 0.6240
# Epoch 47/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7823 - accuracy: 0.9895 - iou_score: 0.8208 - val_loss: 0.8273 - val_accuracy: 0.9743 - val_iou_score: 0.6549
# Epoch 48/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7823 - accuracy: 0.9895 - iou_score: 0.8203 - val_loss: 0.8303 - val_accuracy: 0.9718 - val_iou_score: 0.6443
# Epoch 49/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7825 - accuracy: 0.9895 - iou_score: 0.8198 - val_loss: 0.8294 - val_accuracy: 0.9710 - val_iou_score: 0.6457
# Epoch 50/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.7822 - accuracy: 0.9897 - iou_score: 0.8205 - val_loss: 0.8323 - val_accuracy: 0.9718 - val_iou_score: 0.6361
# Epoch 51/100
# 691/691 [==============================] - 86s 124ms/step - loss: 0.7816 - accuracy: 0.9899 - iou_score: 0.8233 - val_loss: 0.8304 - val_accuracy: 0.9704 - val_iou_score: 0.6426
# Epoch 52/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7814 - accuracy: 0.9899 - iou_score: 0.8242 - val_loss: 0.8261 - val_accuracy: 0.9751 - val_iou_score: 0.6608
# Epoch 53/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7813 - accuracy: 0.9899 - iou_score: 0.8244 - val_loss: 0.8280 - val_accuracy: 0.9738 - val_iou_score: 0.6522
# Epoch 54/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7816 - accuracy: 0.9900 - iou_score: 0.8236 - val_loss: 0.8295 - val_accuracy: 0.9737 - val_iou_score: 0.6467
# Epoch 55/100
# 691/691 [==============================] - 87s 126ms/step - loss: 0.7813 - accuracy: 0.9901 - iou_score: 0.8239 - val_loss: 0.8271 - val_accuracy: 0.9758 - val_iou_score: 0.6543
# Epoch 56/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7819 - accuracy: 0.9897 - iou_score: 0.8250 - val_loss: 0.8252 - val_accuracy: 0.9752 - val_iou_score: 0.6646
# Epoch 57/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7805 - accuracy: 0.9904 - iou_score: 0.8282 - val_loss: 0.8241 - val_accuracy: 0.9767 - val_iou_score: 0.6681
# Epoch 58/100
# 691/691 [==============================] - 86s 124ms/step - loss: 0.7801 - accuracy: 0.9907 - iou_score: 0.8293 - val_loss: 0.8256 - val_accuracy: 0.9763 - val_iou_score: 0.6622
# Epoch 59/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7804 - accuracy: 0.9904 - iou_score: 0.8280 - val_loss: 0.8239 - val_accuracy: 0.9761 - val_iou_score: 0.6705
# Epoch 60/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7797 - accuracy: 0.9907 - iou_score: 0.8312 - val_loss: 0.8250 - val_accuracy: 0.9765 - val_iou_score: 0.6651
# Epoch 61/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7795 - accuracy: 0.9908 - iou_score: 0.8322 - val_loss: 0.8213 - val_accuracy: 0.9764 - val_iou_score: 0.6799
# Epoch 62/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.7792 - accuracy: 0.9909 - iou_score: 0.8338 - val_loss: 0.8245 - val_accuracy: 0.9764 - val_iou_score: 0.6693
# Epoch 63/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7786 - accuracy: 0.9911 - iou_score: 0.8360 - val_loss: 0.8210 - val_accuracy: 0.9776 - val_iou_score: 0.6825
# Epoch 64/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.7786 - accuracy: 0.9910 - iou_score: 0.8361 - val_loss: 0.8217 - val_accuracy: 0.9768 - val_iou_score: 0.6783
# Epoch 65/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7786 - accuracy: 0.9911 - iou_score: 0.8360 - val_loss: 0.8195 - val_accuracy: 0.9779 - val_iou_score: 0.6877
# Epoch 66/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7789 - accuracy: 0.9910 - iou_score: 0.8348 - val_loss: 0.8208 - val_accuracy: 0.9780 - val_iou_score: 0.6833
# Epoch 67/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7783 - accuracy: 0.9911 - iou_score: 0.8373 - val_loss: 0.8221 - val_accuracy: 0.9776 - val_iou_score: 0.6771
# Epoch 68/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.7789 - accuracy: 0.9909 - iou_score: 0.8348 - val_loss: 0.8244 - val_accuracy: 0.9771 - val_iou_score: 0.6678
# Epoch 69/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7787 - accuracy: 0.9910 - iou_score: 0.8355 - val_loss: 0.8212 - val_accuracy: 0.9771 - val_iou_score: 0.6797
# Epoch 70/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.7786 - accuracy: 0.9909 - iou_score: 0.8358 - val_loss: 0.8219 - val_accuracy: 0.9757 - val_iou_score: 0.6774
# Epoch 71/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7783 - accuracy: 0.9910 - iou_score: 0.8376 - val_loss: 0.8222 - val_accuracy: 0.9756 - val_iou_score: 0.6764
# Epoch 72/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7779 - accuracy: 0.9913 - iou_score: 0.8392 - val_loss: 0.8218 - val_accuracy: 0.9775 - val_iou_score: 0.6786
# Epoch 73/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7775 - accuracy: 0.9914 - iou_score: 0.8406 - val_loss: 0.8189 - val_accuracy: 0.9776 - val_iou_score: 0.6916
# Epoch 74/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7779 - accuracy: 0.9913 - iou_score: 0.8390 - val_loss: 0.8183 - val_accuracy: 0.9790 - val_iou_score: 0.6947
# Epoch 75/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7776 - accuracy: 0.9913 - iou_score: 0.8406 - val_loss: 0.8206 - val_accuracy: 0.9779 - val_iou_score: 0.6842
# Epoch 76/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.7771 - accuracy: 0.9916 - iou_score: 0.8421 - val_loss: 0.8195 - val_accuracy: 0.9784 - val_iou_score: 0.6881
# Epoch 77/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.7767 - accuracy: 0.9917 - iou_score: 0.8443 - val_loss: 0.8203 - val_accuracy: 0.9782 - val_iou_score: 0.6856
# Epoch 78/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7768 - accuracy: 0.9916 - iou_score: 0.8439 - val_loss: 0.8207 - val_accuracy: 0.9769 - val_iou_score: 0.6825
# Epoch 79/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7769 - accuracy: 0.9917 - iou_score: 0.8433 - val_loss: 0.8217 - val_accuracy: 0.9759 - val_iou_score: 0.6801
# Epoch 80/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.7770 - accuracy: 0.9916 - iou_score: 0.8429 - val_loss: 0.8197 - val_accuracy: 0.9780 - val_iou_score: 0.6885
# Epoch 81/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7766 - accuracy: 0.9917 - iou_score: 0.8445 - val_loss: 0.8228 - val_accuracy: 0.9779 - val_iou_score: 0.6755
# Epoch 82/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7767 - accuracy: 0.9918 - iou_score: 0.8442 - val_loss: 0.8231 - val_accuracy: 0.9767 - val_iou_score: 0.6756
# Epoch 83/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7764 - accuracy: 0.9918 - iou_score: 0.8453 - val_loss: 0.8219 - val_accuracy: 0.9766 - val_iou_score: 0.6801
# Epoch 84/100
# 691/691 [==============================] - 86s 124ms/step - loss: 0.7763 - accuracy: 0.9919 - iou_score: 0.8464 - val_loss: 0.8232 - val_accuracy: 0.9770 - val_iou_score: 0.6727
# Epoch 85/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7763 - accuracy: 0.9919 - iou_score: 0.8461 - val_loss: 0.8222 - val_accuracy: 0.9774 - val_iou_score: 0.6763
# Epoch 86/100
# 691/691 [==============================] - 86s 124ms/step - loss: 0.7759 - accuracy: 0.9920 - iou_score: 0.8477 - val_loss: 0.8236 - val_accuracy: 0.9770 - val_iou_score: 0.6711
# Epoch 87/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7761 - accuracy: 0.9919 - iou_score: 0.8467 - val_loss: 0.8231 - val_accuracy: 0.9765 - val_iou_score: 0.6731
# Epoch 88/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7759 - accuracy: 0.9919 - iou_score: 0.8476 - val_loss: 0.8218 - val_accuracy: 0.9784 - val_iou_score: 0.6791
# Epoch 89/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.7768 - accuracy: 0.9918 - iou_score: 0.8437 - val_loss: 0.8226 - val_accuracy: 0.9765 - val_iou_score: 0.6740
# Epoch 90/100
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7764 - accuracy: 0.9917 - iou_score: 0.8455 - val_loss: 0.8170 - val_accuracy: 0.9788 - val_iou_score: 0.6984
# Epoch 91/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7756 - accuracy: 0.9920 - iou_score: 0.8489 - val_loss: 0.8182 - val_accuracy: 0.9784 - val_iou_score: 0.6948
# Epoch 92/100
# 691/691 [==============================] - 85s 124ms/step - loss: 0.7752 - accuracy: 0.9922 - iou_score: 0.8508 - val_loss: 0.8202 - val_accuracy: 0.9772 - val_iou_score: 0.6854
# Epoch 93/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.7752 - accuracy: 0.9923 - iou_score: 0.8508 - val_loss: 0.8194 - val_accuracy: 0.9770 - val_iou_score: 0.6882
# Epoch 94/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.7754 - accuracy: 0.9922 - iou_score: 0.8502 - val_loss: 0.8183 - val_accuracy: 0.9777 - val_iou_score: 0.6936
# Epoch 95/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7754 - accuracy: 0.9921 - iou_score: 0.8498 - val_loss: 0.8157 - val_accuracy: 0.9781 - val_iou_score: 0.7047
# Epoch 96/100
# 691/691 [==============================] - 85s 123ms/step - loss: 0.7749 - accuracy: 0.9922 - iou_score: 0.8526 - val_loss: 0.8148 - val_accuracy: 0.9792 - val_iou_score: 0.7097
# Epoch 97/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7749 - accuracy: 0.9923 - iou_score: 0.8526 - val_loss: 0.8184 - val_accuracy: 0.9775 - val_iou_score: 0.6923
# Epoch 98/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7748 - accuracy: 0.9923 - iou_score: 0.8527 - val_loss: 0.8155 - val_accuracy: 0.9796 - val_iou_score: 0.7058
# Epoch 99/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7753 - accuracy: 0.9921 - iou_score: 0.8504 - val_loss: 0.8191 - val_accuracy: 0.9779 - val_iou_score: 0.6913
# Epoch 100/100
# 691/691 [==============================] - 86s 125ms/step - loss: 0.7754 - accuracy: 0.9921 - iou_score: 0.8502 - val_loss: 0.8144 - val_accuracy: 0.9796 - val_iou_score: 0.7106

# %%
#plot the training and validation IoU and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from keras.models import load_model

#Load model for prediction or continue training

#For continuing training....
#The following gives an error: Unknown loss function: dice_loss_plus_1focal_loss
#This is because the model does not save loss function and metrics. So to compile and 
#continue training we need to provide these as custom_objects.

# my_model = load_model('saved_models/brats_3d_100epochs_simple_unet_weighted_dice.hdf5')

#So let us add the loss as custom object... but the following throws another error...
#Unknown metric function: iou_score

# my_model = load_model('saved_models/brats_3d_100epochs_simple_unet_weighted_dice.hdf5', 
#                       custom_objects={'dice_loss_plus_1focal_loss': total_loss})

#Now, let us add the iou_score function we used during our initial training
my_model = load_model('brats_2020_2021_3d_first.hdf5', 
                      custom_objects={'dice_loss_plus_1focal_loss': total_loss,
                                      'iou_score':sm.metrics.IOUScore(threshold=0.5)})

#Now all set to continue the training process. 
history2=my_model.fit(train_img_datagen,
          steps_per_epoch=steps_per_epoch,
          epochs=1,
          verbose=1,
          validation_data=val_img_datagen,
          validation_steps=val_steps_per_epoch,
          )
# Out:
# 2025-03-31 21:49:05.524940: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 691/691 [==============================] - ETA: 0s - loss: 0.7745 - accuracy: 0.9924 - iou_score: 0.8543
# 2025-03-31 21:50:27.021650: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 691/691 [==============================] - 87s 125ms/step - loss: 0.7745 - accuracy: 0.9924 - iou_score: 0.8543 - val_loss: 0.8154 - val_accuracy: 0.9792 - val_iou_score: 0.7064

# %%
my_model = load_model('brats_2020_2021_3d_first.hdf5', 
                      compile=False)


#Verify IoU on a batch of images from the test dataset
#Using built in keras function for IoU
#Only works on TF > 2.0
from keras.metrics import MeanIoU

batch_size=8 #Check IoU for a batch of images
test_img_datagen = imageLoader(val_img_dir, val_img_list, 
                                val_mask_dir, val_mask_list, batch_size)

#Verify generator.... In python 3 next() is renamed as __next__()
test_image_batch, test_mask_batch = test_img_datagen.__next__()

test_mask_batch_argmax = np.argmax(test_mask_batch, axis=4)
test_pred_batch = my_model.predict(test_image_batch)
test_pred_batch_argmax = np.argmax(test_pred_batch, axis=4)

n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(test_pred_batch_argmax, test_mask_batch_argmax)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# 1/1 [==============================] - 5s 5s/step
# Mean IoU = 0.81539834

# %%
#Predict on a few test images, one at a time
#Try images: 
from keras.models import load_model 

my_model = load_model('first/brats_2020_2021_3d_first.hdf5', compile=False) 

import numpy as np 

img_num = 57

test_img = np.load("2020_2021_Validation/images/image_"+str(img_num)+".npy")

test_mask = np.load("2020_2021_Validation/masks/mask_"+str(img_num)+".npy")
test_mask_argmax=np.argmax(test_mask, axis=3)

test_img_input = np.expand_dims(test_img, axis=0)
test_prediction = my_model.predict(test_img_input)
test_prediction_argmax=np.argmax(test_prediction, axis=4)[0,:,:,:]


# print(test_prediction_argmax.shape)
# print(test_mask_argmax.shape)
# print(np.unique(test_prediction_argmax))


#Plot individual slices from test predictions for verification
from matplotlib import pyplot as plt
import random

#n_slice=random.randint(0, test_prediction_argmax.shape[2])
n_slice = 55
plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,n_slice,1], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_argmax[:,:,n_slice])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction_argmax[:,:, n_slice])
plt.show()
# Out:
# 1/1 [==============================] - 4s 4s/step
