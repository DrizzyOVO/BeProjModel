# %%
#from tifffile import imsave, imread
import os
import numpy as np

def load_img(img_dir, img_list):
    images=[]
    for i, image_name in enumerate(img_list):    
        if (image_name.split('.')[1] == 'npy'):
            
            image = np.load(img_dir+image_name)
                      
            images.append(image)
    images = np.array(images)
    
    return(images)

def imageLoader(img_dir, img_list, mask_dir, mask_list, batch_size):

    L = len(img_list)

    #keras needs the generator infinite, so we will use while true  
    while True:

        batch_start = 0
        batch_end = batch_size

        while batch_start < L:
            limit = min(batch_end, L)
                       
            X = load_img(img_dir, img_list[batch_start:limit])
            Y = load_img(mask_dir, mask_list[batch_start:limit])

            yield (X,Y) #a tuple with two numpy arrays with batch_size samples     

            batch_start += batch_size   
            batch_end += batch_size

# %%
import os
import numpy as np
# from custom_datagen import ImageLoader
import tensorflow as tf
import keras
from matplotlib import pyplot as plt
import glob
import random
# Out:
# 2025-04-28 14:03:53.944208: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-28 14:03:53.981293: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_img_dir = "2020_2021_Dataset/images/"
train_mask_dir = "2020_2021_Dataset/masks/"

img_list = os.listdir(train_img_dir)
msk_list = os.listdir(train_mask_dir)

num_images = len(os.listdir(train_img_dir))

img_num = random.randint(0,num_images-1)
test_img = np.load(train_img_dir+img_list[img_num])
test_mask = np.load(train_mask_dir+msk_list[img_num])
test_mask = np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
import pandas as pd
columns = ['0','1', '2', '3']
df = pd.DataFrame(columns=columns)
train_mask_list = sorted(glob.glob('2020_2021_Dataset/masks/*.npy'))
for img in range(len(train_mask_list)):
    # print(img)
    temp_image=np.load(train_mask_list[img])
    temp_image = np.argmax(temp_image, axis=3)
    val, counts = np.unique(temp_image, return_counts=True)
    zipped = zip(columns, counts)
    conts_dict = dict(zipped)
    
    df = df.append(conts_dict, ignore_index=True)

label_0 = df['0'].sum()
label_1 = df['1'].sum()
label_2 = df['1'].sum()
label_3 = df['3'].sum()
total_labels = label_0 + label_1 + label_2 + label_3
n_classes = 4
#Class weights claculation: n_samples / (n_classes * n_samples_for_class)
wt0 = round((total_labels/(n_classes*label_0)), 2) #round to 2 decimals
wt1 = round((total_labels/(n_classes*label_1)), 2)
wt2 = round((total_labels/(n_classes*label_2)), 2)
wt3 = round((total_labels/(n_classes*label_3)), 2)

#Weights are: 0.26, 22.53, 22.53, 26.21
#wt0, wt1, wt2, wt3 = 0.26, 22.53, 22.53, 26.21
#These weihts can be used for Dice loss
# Out:
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# ...
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_601/3595086010.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)

# %%
#Define the image generators for training and validation

train_img_dir = "2020_2021_Dataset/images/"
train_mask_dir = "2020_2021_Dataset/masks/"

val_img_dir = "2020_2021_Validation/images/"
val_mask_dir = "2020_2021_Validation/masks/"

train_img_list=os.listdir(train_img_dir)
train_mask_list = os.listdir(train_mask_dir)

val_img_list=os.listdir(val_img_dir)
val_mask_list = os.listdir(val_mask_dir)

# %%
batch_size = 2

train_img_datagen = imageLoader(train_img_dir, train_img_list, 
                                train_mask_dir, train_mask_list, batch_size)

val_img_datagen = imageLoader(val_img_dir, val_img_list, 
                                val_mask_dir, val_mask_list, batch_size)

#Verify generator.... In python 3 next() is renamed as __next__()
img, msk = train_img_datagen.__next__()

img_num = random.randint(0,img.shape[0]-1)
test_img=img[img_num]
test_mask=msk[img_num]
test_mask=np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
import tensorflow as tf
print(tf.__version__)
import keras
print(keras.__version__)
# Out:
# 2.12.0
# 2.12.0

# %%
#Define loss, metrics and optimizer to be used for training
wt0, wt1, wt2, wt3 = 0.25,0.25,0.25,0.25
import segmentation_models_3D as sm
dice_loss = sm.losses.DiceLoss(class_weights=np.array([wt0, wt1, wt2, wt3])) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

metrics = ['accuracy', sm.metrics.IOUScore(threshold=0.5)]

LR = 0.0001
optim = keras.optimizers.Adam(LR)
# Out:
# Segmentation Models: using `keras` framework.

# %%
from keras.models import Model
from keras.layers import Input, Conv3D, MaxPooling3D, concatenate, Conv3DTranspose, BatchNormalization, Dropout, Lambda
from keras.optimizers import Adam
from keras.metrics import MeanIoU

kernel_initializer =  'he_uniform' #Try others if you want

def simple_unet_model(IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS, num_classes):
#Build the model
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(s)
    c1 = Dropout(0.1)(c1)
    c1 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c1)
    p1 = MaxPooling3D((2, 2, 2))(c1)
    
    c2 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c2)
    p2 = MaxPooling3D((2, 2, 2))(c2)
     
    c3 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c3)
    p3 = MaxPooling3D((2, 2, 2))(c3)
     
    c4 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c4)
    p4 = MaxPooling3D(pool_size=(2, 2, 2))(c4)
     
    c5 = Conv3D(256, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv3D(256, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c5)
    
    #Expansive path 
    u6 = Conv3DTranspose(128, (2, 2, 2), strides=(2, 2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c6)
     
    u7 = Conv3DTranspose(64, (2, 2, 2), strides=(2, 2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c7)
     
    u8 = Conv3DTranspose(32, (2, 2, 2), strides=(2, 2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c8)
     
    u9 = Conv3DTranspose(16, (2, 2, 2), strides=(2, 2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1])
    c9 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c9)
     
    outputs = Conv3D(num_classes, (1, 1, 1), activation='softmax')(c9)
     
    model = Model(inputs=[inputs], outputs=[outputs])
    #compile model outside of this function to make it flexible. 
    model.summary()
    
    return model

# %%
#Fit the model 

steps_per_epoch = len(train_img_list)//batch_size
val_steps_per_epoch = len(val_img_list)//batch_size


# from simple_3d_unet import simple_unet_model

model = simple_unet_model(IMG_HEIGHT=128, 
                          IMG_WIDTH=128, 
                          IMG_DEPTH=128, 
                          IMG_CHANNELS=3, 
                          num_classes=4)

model.compile(optimizer = optim, loss=total_loss, metrics=metrics)
print(model.summary())

print(model.input_shape)
print(model.output_shape)

history=model.fit(train_img_datagen,
          steps_per_epoch=steps_per_epoch,
          epochs=250,
          verbose=1,
          validation_data=val_img_datagen,
          validation_steps=val_steps_per_epoch,
          )

model.save('brats_2020_2021_3d_final_250.hdf5')
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 28, 3)]
#
#  conv3d_19 (Conv3D)             (None, 128, 128, 12  1312        ['input_2[0][0]']
#                                 8, 16)
#
#  dropout_9 (Dropout)            (None, 128, 128, 12  0           ['conv3d_19[0][0]']
#                                 8, 16)
#
#  conv3d_20 (Conv3D)             (None, 128, 128, 12  6928        ['dropout_9[0][0]']
#                                 8, 16)
#
#  max_pooling3d_4 (MaxPooling3D)  (None, 64, 64, 64,   0          ['conv3d_20[0][0]']
#                                 16)
#
#  conv3d_21 (Conv3D)             (None, 64, 64, 64,   13856       ['max_pooling3d_4[0][0]']
#                                 32)
#
#  dropout_10 (Dropout)           (None, 64, 64, 64,   0           ['conv3d_21[0][0]']
#                                 32)
#
#  conv3d_22 (Conv3D)             (None, 64, 64, 64,   27680       ['dropout_10[0][0]']
#                                 32)
#
#  max_pooling3d_5 (MaxPooling3D)  (None, 32, 32, 32,   0          ['conv3d_22[0][0]']
#                                 32)
#
#  conv3d_23 (Conv3D)             (None, 32, 32, 32,   55360       ['max_pooling3d_5[0][0]']
#                                 64)
#
#  dropout_11 (Dropout)           (None, 32, 32, 32,   0           ['conv3d_23[0][0]']
#                                 64)
#
#  conv3d_24 (Conv3D)             (None, 32, 32, 32,   110656      ['dropout_11[0][0]']
#                                 64)
#
#  max_pooling3d_6 (MaxPooling3D)  (None, 16, 16, 16,   0          ['conv3d_24[0][0]']
#                                 64)
#
#  conv3d_25 (Conv3D)             (None, 16, 16, 16,   221312      ['max_pooling3d_6[0][0]']
#                                 128)
#
#  dropout_12 (Dropout)           (None, 16, 16, 16,   0           ['conv3d_25[0][0]']
#                                 128)
#
#  conv3d_26 (Conv3D)             (None, 16, 16, 16,   442496      ['dropout_12[0][0]']
#                                 128)
#
#  max_pooling3d_7 (MaxPooling3D)  (None, 8, 8, 8, 128  0          ['conv3d_26[0][0]']
#                                 )
#
#  conv3d_27 (Conv3D)             (None, 8, 8, 8, 256  884992      ['max_pooling3d_7[0][0]']
#                                 )
#
#  dropout_13 (Dropout)           (None, 8, 8, 8, 256  0           ['conv3d_27[0][0]']
#                                 )
#
#  conv3d_28 (Conv3D)             (None, 8, 8, 8, 256  1769728     ['dropout_13[0][0]']
#                                 )
#
#  conv3d_transpose_4 (Conv3DTran  (None, 16, 16, 16,   262272     ['conv3d_28[0][0]']
#  spose)                         128)
#
#  concatenate_4 (Concatenate)    (None, 16, 16, 16,   0           ['conv3d_transpose_4[0][0]',
#                                 256)                              'conv3d_26[0][0]']
#
#  conv3d_29 (Conv3D)             (None, 16, 16, 16,   884864      ['concatenate_4[0][0]']
#                                 128)
#
#  dropout_14 (Dropout)           (None, 16, 16, 16,   0           ['conv3d_29[0][0]']
#                                 128)
#
#  conv3d_30 (Conv3D)             (None, 16, 16, 16,   442496      ['dropout_14[0][0]']
#                                 128)
#
#  conv3d_transpose_5 (Conv3DTran  (None, 32, 32, 32,   65600      ['conv3d_30[0][0]']
#  spose)                         64)
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_5[0][0]',
#                                 128)                              'conv3d_24[0][0]']
#
#  conv3d_31 (Conv3D)             (None, 32, 32, 32,   221248      ['concatenate_5[0][0]']
#                                 64)
#
#  dropout_15 (Dropout)           (None, 32, 32, 32,   0           ['conv3d_31[0][0]']
#                                 64)
#
#  conv3d_32 (Conv3D)             (None, 32, 32, 32,   110656      ['dropout_15[0][0]']
#                                 64)
#
#  conv3d_transpose_6 (Conv3DTran  (None, 64, 64, 64,   16416      ['conv3d_32[0][0]']
#  spose)                         32)
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 64,   0           ['conv3d_transpose_6[0][0]',
#                                 64)                               'conv3d_22[0][0]']
#
#  conv3d_33 (Conv3D)             (None, 64, 64, 64,   55328       ['concatenate_6[0][0]']
#                                 32)
#
#  dropout_16 (Dropout)           (None, 64, 64, 64,   0           ['conv3d_33[0][0]']
#                                 32)
#
#  conv3d_34 (Conv3D)             (None, 64, 64, 64,   27680       ['dropout_16[0][0]']
#                                 32)
#
#  conv3d_transpose_7 (Conv3DTran  (None, 128, 128, 12  4112       ['conv3d_34[0][0]']
#  spose)                         8, 16)
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 12  0           ['conv3d_transpose_7[0][0]',
#                                 8, 32)                            'conv3d_20[0][0]']
#
#  conv3d_35 (Conv3D)             (None, 128, 128, 12  13840       ['concatenate_7[0][0]']
#                                 8, 16)
#
#  dropout_17 (Dropout)           (None, 128, 128, 12  0           ['conv3d_35[0][0]']
#                                 8, 16)
#
#  conv3d_36 (Conv3D)             (None, 128, 128, 12  6928        ['dropout_17[0][0]']
#                                 8, 16)
#
#  conv3d_37 (Conv3D)             (None, 128, 128, 12  68          ['conv3d_36[0][0]']
#                                 8, 4)
#
# ==================================================================================================
# Total params: 5,645,828
# Trainable params: 5,645,828
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 28, 3)]
#
#  conv3d_19 (Conv3D)             (None, 128, 128, 12  1312        ['input_2[0][0]']
#                                 8, 16)
#
#  dropout_9 (Dropout)            (None, 128, 128, 12  0           ['conv3d_19[0][0]']
#                                 8, 16)
#
#  conv3d_20 (Conv3D)             (None, 128, 128, 12  6928        ['dropout_9[0][0]']
#                                 8, 16)
#
#  max_pooling3d_4 (MaxPooling3D)  (None, 64, 64, 64,   0          ['conv3d_20[0][0]']
#                                 16)
#
#  conv3d_21 (Conv3D)             (None, 64, 64, 64,   13856       ['max_pooling3d_4[0][0]']
#                                 32)
#
#  dropout_10 (Dropout)           (None, 64, 64, 64,   0           ['conv3d_21[0][0]']
#                                 32)
#
#  conv3d_22 (Conv3D)             (None, 64, 64, 64,   27680       ['dropout_10[0][0]']
#                                 32)
#
#  max_pooling3d_5 (MaxPooling3D)  (None, 32, 32, 32,   0          ['conv3d_22[0][0]']
#                                 32)
#
#  conv3d_23 (Conv3D)             (None, 32, 32, 32,   55360       ['max_pooling3d_5[0][0]']
#                                 64)
#
#  dropout_11 (Dropout)           (None, 32, 32, 32,   0           ['conv3d_23[0][0]']
#                                 64)
#
#  conv3d_24 (Conv3D)             (None, 32, 32, 32,   110656      ['dropout_11[0][0]']
#                                 64)
#
#  max_pooling3d_6 (MaxPooling3D)  (None, 16, 16, 16,   0          ['conv3d_24[0][0]']
#                                 64)
#
#  conv3d_25 (Conv3D)             (None, 16, 16, 16,   221312      ['max_pooling3d_6[0][0]']
#                                 128)
#
#  dropout_12 (Dropout)           (None, 16, 16, 16,   0           ['conv3d_25[0][0]']
#                                 128)
#
#  conv3d_26 (Conv3D)             (None, 16, 16, 16,   442496      ['dropout_12[0][0]']
#                                 128)
#
#  max_pooling3d_7 (MaxPooling3D)  (None, 8, 8, 8, 128  0          ['conv3d_26[0][0]']
#                                 )
#
#  conv3d_27 (Conv3D)             (None, 8, 8, 8, 256  884992      ['max_pooling3d_7[0][0]']
#                                 )
#
#  dropout_13 (Dropout)           (None, 8, 8, 8, 256  0           ['conv3d_27[0][0]']
#                                 )
#
#  conv3d_28 (Conv3D)             (None, 8, 8, 8, 256  1769728     ['dropout_13[0][0]']
#                                 )
#
#  conv3d_transpose_4 (Conv3DTran  (None, 16, 16, 16,   262272     ['conv3d_28[0][0]']
#  spose)                         128)
#
#  concatenate_4 (Concatenate)    (None, 16, 16, 16,   0           ['conv3d_transpose_4[0][0]',
#                                 256)                              'conv3d_26[0][0]']
#
#  conv3d_29 (Conv3D)             (None, 16, 16, 16,   884864      ['concatenate_4[0][0]']
#                                 128)
#
#  dropout_14 (Dropout)           (None, 16, 16, 16,   0           ['conv3d_29[0][0]']
#                                 128)
#
#  conv3d_30 (Conv3D)             (None, 16, 16, 16,   442496      ['dropout_14[0][0]']
#                                 128)
#
#  conv3d_transpose_5 (Conv3DTran  (None, 32, 32, 32,   65600      ['conv3d_30[0][0]']
#  spose)                         64)
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_5[0][0]',
#                                 128)                              'conv3d_24[0][0]']
#
#  conv3d_31 (Conv3D)             (None, 32, 32, 32,   221248      ['concatenate_5[0][0]']
#                                 64)
#
#  dropout_15 (Dropout)           (None, 32, 32, 32,   0           ['conv3d_31[0][0]']
#                                 64)
#
#  conv3d_32 (Conv3D)             (None, 32, 32, 32,   110656      ['dropout_15[0][0]']
#                                 64)
#
#  conv3d_transpose_6 (Conv3DTran  (None, 64, 64, 64,   16416      ['conv3d_32[0][0]']
#  spose)                         32)
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 64,   0           ['conv3d_transpose_6[0][0]',
#                                 64)                               'conv3d_22[0][0]']
#
#  conv3d_33 (Conv3D)             (None, 64, 64, 64,   55328       ['concatenate_6[0][0]']
#                                 32)
#
#  dropout_16 (Dropout)           (None, 64, 64, 64,   0           ['conv3d_33[0][0]']
#                                 32)
#
#  conv3d_34 (Conv3D)             (None, 64, 64, 64,   27680       ['dropout_16[0][0]']
#                                 32)
#
#  conv3d_transpose_7 (Conv3DTran  (None, 128, 128, 12  4112       ['conv3d_34[0][0]']
#  spose)                         8, 16)
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 12  0           ['conv3d_transpose_7[0][0]',
#                                 8, 32)                            'conv3d_20[0][0]']
#
#  conv3d_35 (Conv3D)             (None, 128, 128, 12  13840       ['concatenate_7[0][0]']
#                                 8, 16)
#
#  dropout_17 (Dropout)           (None, 128, 128, 12  0           ['conv3d_35[0][0]']
#                                 8, 16)
#
#  conv3d_36 (Conv3D)             (None, 128, 128, 12  6928        ['dropout_17[0][0]']
#                                 8, 16)
#
#  conv3d_37 (Conv3D)             (None, 128, 128, 12  68          ['conv3d_36[0][0]']
#                                 8, 4)
#
# ==================================================================================================
# Total params: 5,645,828
# Trainable params: 5,645,828
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# (None, 128, 128, 128, 3)
# (None, 128, 128, 128, 4)
# Epoch 1/250
# 2025-04-28 14:14:05.381231: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 667/667 [==============================] - ETA: 0s - loss: 0.9110 - accuracy: 0.9392 - iou_score: 0.3357
# 2025-04-28 14:25:16.649167: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 667/667 [==============================] - 803s 1s/step - loss: 0.9110 - accuracy: 0.9392 - iou_score: 0.3357 - val_loss: 0.9083 - val_accuracy: 0.9246 - val_iou_score: 0.3679
# Epoch 2/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.8681 - accuracy: 0.9650 - iou_score: 0.4760 - val_loss: 0.8897 - val_accuracy: 0.9495 - val_iou_score: 0.4241
# Epoch 3/250
# 667/667 [==============================] - 87s 130ms/step - loss: 0.8481 - accuracy: 0.9720 - iou_score: 0.5410 - val_loss: 0.8728 - val_accuracy: 0.9580 - val_iou_score: 0.4784
# Epoch 4/250
# 667/667 [==============================] - 86s 130ms/step - loss: 0.8297 - accuracy: 0.9764 - iou_score: 0.6090 - val_loss: 0.8676 - val_accuracy: 0.9612 - val_iou_score: 0.4974
# Epoch 5/250
# 667/667 [==============================] - 87s 130ms/step - loss: 0.8173 - accuracy: 0.9795 - iou_score: 0.6575 - val_loss: 0.8619 - val_accuracy: 0.9639 - val_iou_score: 0.5217
# Epoch 6/250
# 667/667 [==============================] - 84s 126ms/step - loss: 0.8098 - accuracy: 0.9814 - iou_score: 0.6890 - val_loss: 0.8586 - val_accuracy: 0.9643 - val_iou_score: 0.5331
# Epoch 7/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.8047 - accuracy: 0.9833 - iou_score: 0.7101 - val_loss: 0.8540 - val_accuracy: 0.9671 - val_iou_score: 0.5479
# Epoch 8/250
# 667/667 [==============================] - 84s 125ms/step - loss: 0.8023 - accuracy: 0.9839 - iou_score: 0.7202 - val_loss: 0.8520 - val_accuracy: 0.9666 - val_iou_score: 0.5551
# Epoch 9/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7997 - accuracy: 0.9847 - iou_score: 0.7313 - val_loss: 0.8494 - val_accuracy: 0.9690 - val_iou_score: 0.5636
# Epoch 10/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7970 - accuracy: 0.9856 - iou_score: 0.7429 - val_loss: 0.8456 - val_accuracy: 0.9716 - val_iou_score: 0.5768
# Epoch 11/250
# 667/667 [==============================] - 84s 126ms/step - loss: 0.7955 - accuracy: 0.9861 - iou_score: 0.7496 - val_loss: 0.8400 - val_accuracy: 0.9731 - val_iou_score: 0.5961
# Epoch 12/250
# 667/667 [==============================] - 84s 126ms/step - loss: 0.7938 - accuracy: 0.9867 - iou_score: 0.7570 - val_loss: 0.8401 - val_accuracy: 0.9734 - val_iou_score: 0.5967
# Epoch 13/250
# 667/667 [==============================] - 86s 130ms/step - loss: 0.7930 - accuracy: 0.9869 - iou_score: 0.7604 - val_loss: 0.8371 - val_accuracy: 0.9737 - val_iou_score: 0.6071
# Epoch 14/250
# 667/667 [==============================] - 86s 130ms/step - loss: 0.7916 - accuracy: 0.9873 - iou_score: 0.7666 - val_loss: 0.8382 - val_accuracy: 0.9716 - val_iou_score: 0.6026
# Epoch 15/250
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7913 - accuracy: 0.9874 - iou_score: 0.7686 - val_loss: 0.8379 - val_accuracy: 0.9736 - val_iou_score: 0.6045
# Epoch 16/250
# 667/667 [==============================] - 86s 130ms/step - loss: 0.7893 - accuracy: 0.9881 - iou_score: 0.7774 - val_loss: 0.8355 - val_accuracy: 0.9725 - val_iou_score: 0.6108
# Epoch 17/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7882 - accuracy: 0.9884 - iou_score: 0.7823 - val_loss: 0.8381 - val_accuracy: 0.9677 - val_iou_score: 0.6033
# Epoch 18/250
# 667/667 [==============================] - 85s 128ms/step - loss: 0.7874 - accuracy: 0.9887 - iou_score: 0.7855 - val_loss: 0.8412 - val_accuracy: 0.9641 - val_iou_score: 0.5918
# Epoch 19/250
# 667/667 [==============================] - 86s 130ms/step - loss: 0.7868 - accuracy: 0.9890 - iou_score: 0.7890 - val_loss: 0.8424 - val_accuracy: 0.9631 - val_iou_score: 0.5872
# Epoch 20/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7866 - accuracy: 0.9890 - iou_score: 0.7900 - val_loss: 0.8457 - val_accuracy: 0.9585 - val_iou_score: 0.5781
# Epoch 21/250
# 667/667 [==============================] - 85s 128ms/step - loss: 0.7853 - accuracy: 0.9893 - iou_score: 0.7962 - val_loss: 0.8372 - val_accuracy: 0.9689 - val_iou_score: 0.6092
# Epoch 22/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7849 - accuracy: 0.9895 - iou_score: 0.7977 - val_loss: 0.8299 - val_accuracy: 0.9741 - val_iou_score: 0.6349
# Epoch 23/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7849 - accuracy: 0.9894 - iou_score: 0.7984 - val_loss: 0.8348 - val_accuracy: 0.9730 - val_iou_score: 0.6152
# Epoch 24/250
# 667/667 [==============================] - 84s 125ms/step - loss: 0.7832 - accuracy: 0.9900 - iou_score: 0.8058 - val_loss: 0.8265 - val_accuracy: 0.9775 - val_iou_score: 0.6491
# Epoch 25/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7818 - accuracy: 0.9903 - iou_score: 0.8121 - val_loss: 0.8279 - val_accuracy: 0.9776 - val_iou_score: 0.6443
# Epoch 26/250
# 667/667 [==============================] - 86s 130ms/step - loss: 0.7819 - accuracy: 0.9903 - iou_score: 0.8119 - val_loss: 0.8279 - val_accuracy: 0.9774 - val_iou_score: 0.6457
# Epoch 27/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7818 - accuracy: 0.9904 - iou_score: 0.8127 - val_loss: 0.8236 - val_accuracy: 0.9784 - val_iou_score: 0.6599
# Epoch 28/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7813 - accuracy: 0.9906 - iou_score: 0.8154 - val_loss: 0.8315 - val_accuracy: 0.9765 - val_iou_score: 0.6318
# Epoch 29/250
# 667/667 [==============================] - 84s 125ms/step - loss: 0.7808 - accuracy: 0.9907 - iou_score: 0.8173 - val_loss: 0.8246 - val_accuracy: 0.9781 - val_iou_score: 0.6571
# Epoch 30/250
# 667/667 [==============================] - 84s 126ms/step - loss: 0.7798 - accuracy: 0.9910 - iou_score: 0.8223 - val_loss: 0.8245 - val_accuracy: 0.9785 - val_iou_score: 0.6578
# Epoch 31/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7802 - accuracy: 0.9909 - iou_score: 0.8202 - val_loss: 0.8246 - val_accuracy: 0.9784 - val_iou_score: 0.6595
# Epoch 32/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7794 - accuracy: 0.9911 - iou_score: 0.8240 - val_loss: 0.8267 - val_accuracy: 0.9781 - val_iou_score: 0.6544
# Epoch 33/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7791 - accuracy: 0.9913 - iou_score: 0.8259 - val_loss: 0.8283 - val_accuracy: 0.9770 - val_iou_score: 0.6500
# Epoch 34/250
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7784 - accuracy: 0.9914 - iou_score: 0.8296 - val_loss: 0.8213 - val_accuracy: 0.9799 - val_iou_score: 0.6716
# Epoch 35/250
# 667/667 [==============================] - 87s 130ms/step - loss: 0.7781 - accuracy: 0.9916 - iou_score: 0.8310 - val_loss: 0.8182 - val_accuracy: 0.9797 - val_iou_score: 0.6830
# Epoch 36/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7776 - accuracy: 0.9918 - iou_score: 0.8334 - val_loss: 0.8212 - val_accuracy: 0.9785 - val_iou_score: 0.6716
# Epoch 37/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7777 - accuracy: 0.9917 - iou_score: 0.8330 - val_loss: 0.8223 - val_accuracy: 0.9789 - val_iou_score: 0.6686
# Epoch 38/250
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7776 - accuracy: 0.9917 - iou_score: 0.8336 - val_loss: 0.8191 - val_accuracy: 0.9788 - val_iou_score: 0.6804
# Epoch 39/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7770 - accuracy: 0.9919 - iou_score: 0.8366 - val_loss: 0.8228 - val_accuracy: 0.9776 - val_iou_score: 0.6665
# Epoch 40/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7772 - accuracy: 0.9918 - iou_score: 0.8356 - val_loss: 0.8260 - val_accuracy: 0.9777 - val_iou_score: 0.6578
# Epoch 41/250
# 667/667 [==============================] - 86s 128ms/step - loss: 0.7769 - accuracy: 0.9919 - iou_score: 0.8375 - val_loss: 0.8207 - val_accuracy: 0.9786 - val_iou_score: 0.6749
# Epoch 42/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7765 - accuracy: 0.9920 - iou_score: 0.8390 - val_loss: 0.8203 - val_accuracy: 0.9794 - val_iou_score: 0.6762
# Epoch 43/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7764 - accuracy: 0.9920 - iou_score: 0.8402 - val_loss: 0.8180 - val_accuracy: 0.9796 - val_iou_score: 0.6849
# Epoch 44/250
# 667/667 [==============================] - 86s 130ms/step - loss: 0.7763 - accuracy: 0.9920 - iou_score: 0.8405 - val_loss: 0.8163 - val_accuracy: 0.9798 - val_iou_score: 0.6910
# Epoch 45/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7763 - accuracy: 0.9920 - iou_score: 0.8399 - val_loss: 0.8142 - val_accuracy: 0.9813 - val_iou_score: 0.7010
# Epoch 46/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7759 - accuracy: 0.9921 - iou_score: 0.8423 - val_loss: 0.8155 - val_accuracy: 0.9815 - val_iou_score: 0.6953
# Epoch 47/250
# 667/667 [==============================] - 84s 126ms/step - loss: 0.7755 - accuracy: 0.9922 - iou_score: 0.8443 - val_loss: 0.8124 - val_accuracy: 0.9815 - val_iou_score: 0.7060
# Epoch 48/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7752 - accuracy: 0.9924 - iou_score: 0.8459 - val_loss: 0.8152 - val_accuracy: 0.9796 - val_iou_score: 0.6972
# Epoch 49/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7750 - accuracy: 0.9924 - iou_score: 0.8473 - val_loss: 0.8116 - val_accuracy: 0.9813 - val_iou_score: 0.7104
# Epoch 50/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7756 - accuracy: 0.9923 - iou_score: 0.8438 - val_loss: 0.8114 - val_accuracy: 0.9809 - val_iou_score: 0.7113
# Epoch 51/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7745 - accuracy: 0.9926 - iou_score: 0.8495 - val_loss: 0.8125 - val_accuracy: 0.9799 - val_iou_score: 0.7070
# Epoch 52/250
# 667/667 [==============================] - 84s 125ms/step - loss: 0.7746 - accuracy: 0.9926 - iou_score: 0.8491 - val_loss: 0.8130 - val_accuracy: 0.9801 - val_iou_score: 0.7061
# Epoch 53/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7741 - accuracy: 0.9928 - iou_score: 0.8515 - val_loss: 0.8122 - val_accuracy: 0.9802 - val_iou_score: 0.7084
# Epoch 54/250
# 667/667 [==============================] - 85s 128ms/step - loss: 0.7739 - accuracy: 0.9928 - iou_score: 0.8527 - val_loss: 0.8092 - val_accuracy: 0.9819 - val_iou_score: 0.7208
# Epoch 55/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7737 - accuracy: 0.9929 - iou_score: 0.8540 - val_loss: 0.8092 - val_accuracy: 0.9824 - val_iou_score: 0.7213
# Epoch 56/250
# 667/667 [==============================] - 84s 126ms/step - loss: 0.7739 - accuracy: 0.9929 - iou_score: 0.8531 - val_loss: 0.8096 - val_accuracy: 0.9830 - val_iou_score: 0.7206
# Epoch 57/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7736 - accuracy: 0.9930 - iou_score: 0.8545 - val_loss: 0.8093 - val_accuracy: 0.9828 - val_iou_score: 0.7219
# Epoch 58/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7732 - accuracy: 0.9930 - iou_score: 0.8565 - val_loss: 0.8088 - val_accuracy: 0.9832 - val_iou_score: 0.7217
# Epoch 59/250
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7731 - accuracy: 0.9931 - iou_score: 0.8574 - val_loss: 0.8085 - val_accuracy: 0.9832 - val_iou_score: 0.7247
# Epoch 60/250
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7736 - accuracy: 0.9929 - iou_score: 0.8545 - val_loss: 0.8090 - val_accuracy: 0.9831 - val_iou_score: 0.7219
# Epoch 61/250
# 667/667 [==============================] - 86s 128ms/step - loss: 0.7730 - accuracy: 0.9930 - iou_score: 0.8576 - val_loss: 0.8075 - val_accuracy: 0.9833 - val_iou_score: 0.7285
# Epoch 62/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7732 - accuracy: 0.9930 - iou_score: 0.8568 - val_loss: 0.8125 - val_accuracy: 0.9817 - val_iou_score: 0.7081
# Epoch 63/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7737 - accuracy: 0.9929 - iou_score: 0.8543 - val_loss: 0.8082 - val_accuracy: 0.9827 - val_iou_score: 0.7297
# Epoch 64/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7729 - accuracy: 0.9930 - iou_score: 0.8583 - val_loss: 0.8111 - val_accuracy: 0.9815 - val_iou_score: 0.7133
# Epoch 65/250
# 667/667 [==============================] - 84s 125ms/step - loss: 0.7726 - accuracy: 0.9932 - iou_score: 0.8597 - val_loss: 0.8111 - val_accuracy: 0.9814 - val_iou_score: 0.7134
# Epoch 66/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7722 - accuracy: 0.9933 - iou_score: 0.8620 - val_loss: 0.8070 - val_accuracy: 0.9832 - val_iou_score: 0.7309
# Epoch 67/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7721 - accuracy: 0.9934 - iou_score: 0.8621 - val_loss: 0.8070 - val_accuracy: 0.9836 - val_iou_score: 0.7303
# Epoch 68/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7730 - accuracy: 0.9931 - iou_score: 0.8581 - val_loss: 0.8103 - val_accuracy: 0.9816 - val_iou_score: 0.7148
# Epoch 69/250
# 667/667 [==============================] - 84s 125ms/step - loss: 0.7729 - accuracy: 0.9930 - iou_score: 0.8583 - val_loss: 0.8071 - val_accuracy: 0.9832 - val_iou_score: 0.7297
# Epoch 70/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7720 - accuracy: 0.9933 - iou_score: 0.8631 - val_loss: 0.8062 - val_accuracy: 0.9838 - val_iou_score: 0.7369
# Epoch 71/250
# 667/667 [==============================] - 85s 128ms/step - loss: 0.7720 - accuracy: 0.9934 - iou_score: 0.8626 - val_loss: 0.8067 - val_accuracy: 0.9839 - val_iou_score: 0.7321
# Epoch 72/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7720 - accuracy: 0.9934 - iou_score: 0.8625 - val_loss: 0.8055 - val_accuracy: 0.9840 - val_iou_score: 0.7380
# Epoch 73/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7714 - accuracy: 0.9936 - iou_score: 0.8660 - val_loss: 0.8067 - val_accuracy: 0.9836 - val_iou_score: 0.7329
# Epoch 74/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7715 - accuracy: 0.9936 - iou_score: 0.8659 - val_loss: 0.8062 - val_accuracy: 0.9839 - val_iou_score: 0.7341
# Epoch 75/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7714 - accuracy: 0.9937 - iou_score: 0.8658 - val_loss: 0.8063 - val_accuracy: 0.9836 - val_iou_score: 0.7341
# Epoch 76/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7717 - accuracy: 0.9936 - iou_score: 0.8647 - val_loss: 0.8074 - val_accuracy: 0.9838 - val_iou_score: 0.7293
# Epoch 77/250
# 667/667 [==============================] - 84s 127ms/step - loss: 0.7712 - accuracy: 0.9937 - iou_score: 0.8669 - val_loss: 0.8057 - val_accuracy: 0.9838 - val_iou_score: 0.7398
# Epoch 78/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7711 - accuracy: 0.9937 - iou_score: 0.8679 - val_loss: 0.8050 - val_accuracy: 0.9835 - val_iou_score: 0.7406
# Epoch 79/250
# 667/667 [==============================] - 85s 128ms/step - loss: 0.7710 - accuracy: 0.9937 - iou_score: 0.8688 - val_loss: 0.8065 - val_accuracy: 0.9836 - val_iou_score: 0.7329
# Epoch 80/250
# 667/667 [==============================] - 84s 125ms/step - loss: 0.7710 - accuracy: 0.9936 - iou_score: 0.8687 - val_loss: 0.8069 - val_accuracy: 0.9816 - val_iou_score: 0.7315
# Epoch 81/250
# 667/667 [==============================] - 84s 125ms/step - loss: 0.7709 - accuracy: 0.9937 - iou_score: 0.8691 - val_loss: 0.8069 - val_accuracy: 0.9821 - val_iou_score: 0.7315
# Epoch 82/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7709 - accuracy: 0.9937 - iou_score: 0.8692 - val_loss: 0.8062 - val_accuracy: 0.9830 - val_iou_score: 0.7356
# Epoch 83/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7711 - accuracy: 0.9936 - iou_score: 0.8680 - val_loss: 0.8056 - val_accuracy: 0.9833 - val_iou_score: 0.7375
# Epoch 84/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7708 - accuracy: 0.9936 - iou_score: 0.8695 - val_loss: 0.8064 - val_accuracy: 0.9836 - val_iou_score: 0.7350
# Epoch 85/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7707 - accuracy: 0.9937 - iou_score: 0.8700 - val_loss: 0.8040 - val_accuracy: 0.9840 - val_iou_score: 0.7449
# Epoch 86/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7707 - accuracy: 0.9937 - iou_score: 0.8700 - val_loss: 0.8090 - val_accuracy: 0.9823 - val_iou_score: 0.7232
# Epoch 87/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7705 - accuracy: 0.9938 - iou_score: 0.8711 - val_loss: 0.8034 - val_accuracy: 0.9843 - val_iou_score: 0.7474
# Epoch 88/250
# 667/667 [==============================] - 84s 125ms/step - loss: 0.7703 - accuracy: 0.9939 - iou_score: 0.8724 - val_loss: 0.8066 - val_accuracy: 0.9834 - val_iou_score: 0.7324
# Epoch 89/250
# 667/667 [==============================] - 84s 125ms/step - loss: 0.7704 - accuracy: 0.9939 - iou_score: 0.8717 - val_loss: 0.8057 - val_accuracy: 0.9832 - val_iou_score: 0.7390
# Epoch 90/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7702 - accuracy: 0.9939 - iou_score: 0.8728 - val_loss: 0.8084 - val_accuracy: 0.9820 - val_iou_score: 0.7266
# Epoch 91/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7699 - accuracy: 0.9940 - iou_score: 0.8745 - val_loss: 0.8068 - val_accuracy: 0.9831 - val_iou_score: 0.7333
# Epoch 92/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7697 - accuracy: 0.9941 - iou_score: 0.8757 - val_loss: 0.8080 - val_accuracy: 0.9831 - val_iou_score: 0.7291
# Epoch 93/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7703 - accuracy: 0.9939 - iou_score: 0.8726 - val_loss: 0.8131 - val_accuracy: 0.9815 - val_iou_score: 0.7113
# Epoch 94/250
# 667/667 [==============================] - 85s 128ms/step - loss: 0.7702 - accuracy: 0.9939 - iou_score: 0.8729 - val_loss: 0.8119 - val_accuracy: 0.9824 - val_iou_score: 0.7125
# Epoch 95/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7699 - accuracy: 0.9940 - iou_score: 0.8744 - val_loss: 0.8100 - val_accuracy: 0.9830 - val_iou_score: 0.7205
# Epoch 96/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7697 - accuracy: 0.9941 - iou_score: 0.8760 - val_loss: 0.8125 - val_accuracy: 0.9823 - val_iou_score: 0.7106
# Epoch 97/250
# 667/667 [==============================] - 84s 125ms/step - loss: 0.7697 - accuracy: 0.9941 - iou_score: 0.8758 - val_loss: 0.8093 - val_accuracy: 0.9828 - val_iou_score: 0.7238
# Epoch 98/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7696 - accuracy: 0.9941 - iou_score: 0.8765 - val_loss: 0.8076 - val_accuracy: 0.9836 - val_iou_score: 0.7351
# Epoch 99/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7695 - accuracy: 0.9941 - iou_score: 0.8767 - val_loss: 0.8063 - val_accuracy: 0.9840 - val_iou_score: 0.7370
# Epoch 100/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7696 - accuracy: 0.9941 - iou_score: 0.8763 - val_loss: 0.8099 - val_accuracy: 0.9828 - val_iou_score: 0.7221
# Epoch 101/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7696 - accuracy: 0.9941 - iou_score: 0.8766 - val_loss: 0.8085 - val_accuracy: 0.9836 - val_iou_score: 0.7271
# Epoch 102/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7695 - accuracy: 0.9941 - iou_score: 0.8766 - val_loss: 0.8051 - val_accuracy: 0.9840 - val_iou_score: 0.7424
# Epoch 103/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7691 - accuracy: 0.9943 - iou_score: 0.8788 - val_loss: 0.8096 - val_accuracy: 0.9830 - val_iou_score: 0.7226
# Epoch 104/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7692 - accuracy: 0.9942 - iou_score: 0.8784 - val_loss: 0.8065 - val_accuracy: 0.9838 - val_iou_score: 0.7349
# Epoch 105/250
# 667/667 [==============================] - 85s 128ms/step - loss: 0.7694 - accuracy: 0.9942 - iou_score: 0.8772 - val_loss: 0.8063 - val_accuracy: 0.9840 - val_iou_score: 0.7367
# Epoch 106/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7694 - accuracy: 0.9941 - iou_score: 0.8774 - val_loss: 0.8158 - val_accuracy: 0.9814 - val_iou_score: 0.6992
# Epoch 107/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7698 - accuracy: 0.9940 - iou_score: 0.8753 - val_loss: 0.8132 - val_accuracy: 0.9819 - val_iou_score: 0.7073
# Epoch 108/250
# 667/667 [==============================] - 84s 125ms/step - loss: 0.7698 - accuracy: 0.9940 - iou_score: 0.8750 - val_loss: 0.8092 - val_accuracy: 0.9822 - val_iou_score: 0.7232
# Epoch 109/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7695 - accuracy: 0.9941 - iou_score: 0.8771 - val_loss: 0.8091 - val_accuracy: 0.9823 - val_iou_score: 0.7234
# Epoch 110/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7692 - accuracy: 0.9942 - iou_score: 0.8783 - val_loss: 0.8059 - val_accuracy: 0.9844 - val_iou_score: 0.7368
# Epoch 111/250
# 667/667 [==============================] - 86s 128ms/step - loss: 0.7690 - accuracy: 0.9942 - iou_score: 0.8797 - val_loss: 0.8038 - val_accuracy: 0.9849 - val_iou_score: 0.7465
# Epoch 112/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7691 - accuracy: 0.9942 - iou_score: 0.8792 - val_loss: 0.8104 - val_accuracy: 0.9835 - val_iou_score: 0.7193
# Epoch 113/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7690 - accuracy: 0.9943 - iou_score: 0.8795 - val_loss: 0.8094 - val_accuracy: 0.9828 - val_iou_score: 0.7219
# Epoch 114/250
# ...
# Epoch 168/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7665 - accuracy: 0.9950 - iou_score: 0.8938 - val_loss: 0.7955 - val_accuracy: 0.9869 - val_iou_score: 0.7880
# Epoch 169/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7666 - accuracy: 0.9950 - iou_score: 0.8936 - val_loss: 0.7945 - val_accuracy: 0.9868 - val_iou_score: 0.7979
# Epoch 170/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7665 - accuracy: 0.9951 - iou_score: 0.8940 - val_loss: 0.7949 - val_accuracy: 0.9864 - val_iou_score: 0.7955
# Epoch 171/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7665 - accuracy: 0.9951 - iou_score: 0.8940 - val_loss: 0.7950 - val_accuracy: 0.9865 - val_iou_score: 0.7952
# Epoch 172/250
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7666 - accuracy: 0.9950 - iou_score: 0.8934 - val_loss: 0.7964 - val_accuracy: 0.9857 - val_iou_score: 0.7838
# Epoch 173/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7667 - accuracy: 0.9950 - iou_score: 0.8930 - val_loss: 0.7948 - val_accuracy: 0.9867 - val_iou_score: 0.7921
# Epoch 174/250
# 667/667 [==============================] - 84s 127ms/step - loss: 0.7667 - accuracy: 0.9950 - iou_score: 0.8931 - val_loss: 0.7952 - val_accuracy: 0.9872 - val_iou_score: 0.7935
# Epoch 175/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7666 - accuracy: 0.9950 - iou_score: 0.8937 - val_loss: 0.7963 - val_accuracy: 0.9860 - val_iou_score: 0.7874
# Epoch 176/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7665 - accuracy: 0.9950 - iou_score: 0.8942 - val_loss: 0.7952 - val_accuracy: 0.9862 - val_iou_score: 0.7908
# Epoch 177/250
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7665 - accuracy: 0.9950 - iou_score: 0.8944 - val_loss: 0.7949 - val_accuracy: 0.9870 - val_iou_score: 0.7923
# Epoch 178/250
# 667/667 [==============================] - 85s 128ms/step - loss: 0.7667 - accuracy: 0.9950 - iou_score: 0.8930 - val_loss: 0.7948 - val_accuracy: 0.9869 - val_iou_score: 0.7924
# Epoch 179/250
# 667/667 [==============================] - 85s 128ms/step - loss: 0.7667 - accuracy: 0.9950 - iou_score: 0.8934 - val_loss: 0.7950 - val_accuracy: 0.9871 - val_iou_score: 0.7920
# Epoch 180/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7666 - accuracy: 0.9950 - iou_score: 0.8939 - val_loss: 0.7951 - val_accuracy: 0.9874 - val_iou_score: 0.7918
# Epoch 181/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7666 - accuracy: 0.9950 - iou_score: 0.8938 - val_loss: 0.7938 - val_accuracy: 0.9874 - val_iou_score: 0.8011
# Epoch 182/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7665 - accuracy: 0.9950 - iou_score: 0.8943 - val_loss: 0.7946 - val_accuracy: 0.9873 - val_iou_score: 0.7965
# Epoch 183/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7665 - accuracy: 0.9950 - iou_score: 0.8944 - val_loss: 0.7948 - val_accuracy: 0.9872 - val_iou_score: 0.7952
# Epoch 184/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7665 - accuracy: 0.9950 - iou_score: 0.8945 - val_loss: 0.7946 - val_accuracy: 0.9873 - val_iou_score: 0.7971
# Epoch 185/250
# 667/667 [==============================] - 85s 128ms/step - loss: 0.7665 - accuracy: 0.9950 - iou_score: 0.8943 - val_loss: 0.7949 - val_accuracy: 0.9871 - val_iou_score: 0.7946
# Epoch 186/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7664 - accuracy: 0.9950 - iou_score: 0.8947 - val_loss: 0.7942 - val_accuracy: 0.9873 - val_iou_score: 0.7992
# Epoch 187/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7663 - accuracy: 0.9951 - iou_score: 0.8957 - val_loss: 0.7943 - val_accuracy: 0.9870 - val_iou_score: 0.7987
# Epoch 188/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7663 - accuracy: 0.9951 - iou_score: 0.8957 - val_loss: 0.7950 - val_accuracy: 0.9866 - val_iou_score: 0.7961
# Epoch 189/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7663 - accuracy: 0.9951 - iou_score: 0.8953 - val_loss: 0.7939 - val_accuracy: 0.9872 - val_iou_score: 0.8016
# Epoch 190/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7663 - accuracy: 0.9951 - iou_score: 0.8955 - val_loss: 0.7945 - val_accuracy: 0.9868 - val_iou_score: 0.7954
# Epoch 191/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7664 - accuracy: 0.9950 - iou_score: 0.8947 - val_loss: 0.7942 - val_accuracy: 0.9870 - val_iou_score: 0.7963
# Epoch 192/250
# 667/667 [==============================] - 85s 128ms/step - loss: 0.7664 - accuracy: 0.9950 - iou_score: 0.8949 - val_loss: 0.7940 - val_accuracy: 0.9870 - val_iou_score: 0.8004
# Epoch 193/250
# 667/667 [==============================] - 86s 128ms/step - loss: 0.7665 - accuracy: 0.9950 - iou_score: 0.8940 - val_loss: 0.7945 - val_accuracy: 0.9869 - val_iou_score: 0.7980
# Epoch 194/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7664 - accuracy: 0.9951 - iou_score: 0.8946 - val_loss: 0.7944 - val_accuracy: 0.9874 - val_iou_score: 0.7991
# Epoch 195/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7662 - accuracy: 0.9951 - iou_score: 0.8960 - val_loss: 0.7941 - val_accuracy: 0.9875 - val_iou_score: 0.7970
# Epoch 196/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7663 - accuracy: 0.9951 - iou_score: 0.8956 - val_loss: 0.7940 - val_accuracy: 0.9875 - val_iou_score: 0.7967
# Epoch 197/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7663 - accuracy: 0.9951 - iou_score: 0.8954 - val_loss: 0.7950 - val_accuracy: 0.9872 - val_iou_score: 0.7915
# Epoch 198/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7663 - accuracy: 0.9951 - iou_score: 0.8955 - val_loss: 0.7955 - val_accuracy: 0.9870 - val_iou_score: 0.7894
# Epoch 199/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7662 - accuracy: 0.9952 - iou_score: 0.8961 - val_loss: 0.7944 - val_accuracy: 0.9873 - val_iou_score: 0.7987
# Epoch 200/250
# 667/667 [==============================] - 84s 126ms/step - loss: 0.7662 - accuracy: 0.9952 - iou_score: 0.8965 - val_loss: 0.7949 - val_accuracy: 0.9871 - val_iou_score: 0.7959
# Epoch 201/250
# 667/667 [==============================] - 86s 128ms/step - loss: 0.7664 - accuracy: 0.9951 - iou_score: 0.8955 - val_loss: 0.7947 - val_accuracy: 0.9872 - val_iou_score: 0.7981
# Epoch 202/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7662 - accuracy: 0.9952 - iou_score: 0.8964 - val_loss: 0.7951 - val_accuracy: 0.9871 - val_iou_score: 0.7969
# Epoch 203/250
# 667/667 [==============================] - 84s 127ms/step - loss: 0.7660 - accuracy: 0.9952 - iou_score: 0.8973 - val_loss: 0.7950 - val_accuracy: 0.9871 - val_iou_score: 0.7965
# Epoch 204/250
# 667/667 [==============================] - 84s 127ms/step - loss: 0.7660 - accuracy: 0.9952 - iou_score: 0.8971 - val_loss: 0.7942 - val_accuracy: 0.9873 - val_iou_score: 0.8008
# Epoch 205/250
# 667/667 [==============================] - 85s 128ms/step - loss: 0.7664 - accuracy: 0.9951 - iou_score: 0.8947 - val_loss: 0.7952 - val_accuracy: 0.9866 - val_iou_score: 0.7951
# Epoch 206/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7661 - accuracy: 0.9952 - iou_score: 0.8973 - val_loss: 0.7951 - val_accuracy: 0.9864 - val_iou_score: 0.7963
# Epoch 207/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7660 - accuracy: 0.9952 - iou_score: 0.8973 - val_loss: 0.7960 - val_accuracy: 0.9858 - val_iou_score: 0.7896
# Epoch 208/250
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7658 - accuracy: 0.9953 - iou_score: 0.8985 - val_loss: 0.7947 - val_accuracy: 0.9864 - val_iou_score: 0.7957
# Epoch 209/250
# 667/667 [==============================] - 85s 128ms/step - loss: 0.7657 - accuracy: 0.9953 - iou_score: 0.8991 - val_loss: 0.7948 - val_accuracy: 0.9866 - val_iou_score: 0.7957
# Epoch 210/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7658 - accuracy: 0.9953 - iou_score: 0.8987 - val_loss: 0.7957 - val_accuracy: 0.9866 - val_iou_score: 0.7907
# Epoch 211/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7657 - accuracy: 0.9953 - iou_score: 0.8990 - val_loss: 0.7949 - val_accuracy: 0.9871 - val_iou_score: 0.7939
# Epoch 212/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7657 - accuracy: 0.9953 - iou_score: 0.8989 - val_loss: 0.7951 - val_accuracy: 0.9866 - val_iou_score: 0.7930
# Epoch 213/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7658 - accuracy: 0.9953 - iou_score: 0.8985 - val_loss: 0.7953 - val_accuracy: 0.9868 - val_iou_score: 0.7925
# Epoch 214/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7657 - accuracy: 0.9953 - iou_score: 0.8988 - val_loss: 0.7959 - val_accuracy: 0.9863 - val_iou_score: 0.7885
# Epoch 215/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7657 - accuracy: 0.9953 - iou_score: 0.8992 - val_loss: 0.7948 - val_accuracy: 0.9871 - val_iou_score: 0.7937
# Epoch 216/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7657 - accuracy: 0.9953 - iou_score: 0.8991 - val_loss: 0.7955 - val_accuracy: 0.9867 - val_iou_score: 0.7894
# Epoch 217/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7657 - accuracy: 0.9953 - iou_score: 0.8991 - val_loss: 0.7952 - val_accuracy: 0.9869 - val_iou_score: 0.7917
# Epoch 218/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7668 - accuracy: 0.9948 - iou_score: 0.8927 - val_loss: 0.7954 - val_accuracy: 0.9866 - val_iou_score: 0.7910
# Epoch 219/250
# 667/667 [==============================] - 86s 128ms/step - loss: 0.7659 - accuracy: 0.9952 - iou_score: 0.8981 - val_loss: 0.7953 - val_accuracy: 0.9865 - val_iou_score: 0.7924
# Epoch 220/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7655 - accuracy: 0.9953 - iou_score: 0.9001 - val_loss: 0.7954 - val_accuracy: 0.9864 - val_iou_score: 0.7920
# Epoch 221/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7655 - accuracy: 0.9954 - iou_score: 0.9004 - val_loss: 0.7952 - val_accuracy: 0.9866 - val_iou_score: 0.7937
# Epoch 222/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7655 - accuracy: 0.9954 - iou_score: 0.8999 - val_loss: 0.7950 - val_accuracy: 0.9867 - val_iou_score: 0.7946
# Epoch 223/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7655 - accuracy: 0.9954 - iou_score: 0.9004 - val_loss: 0.7942 - val_accuracy: 0.9871 - val_iou_score: 0.7984
# Epoch 224/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7656 - accuracy: 0.9954 - iou_score: 0.8999 - val_loss: 0.7960 - val_accuracy: 0.9866 - val_iou_score: 0.7894
# Epoch 225/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7654 - accuracy: 0.9954 - iou_score: 0.9008 - val_loss: 0.7944 - val_accuracy: 0.9871 - val_iou_score: 0.8005
# Epoch 226/250
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7657 - accuracy: 0.9954 - iou_score: 0.8991 - val_loss: 0.7948 - val_accuracy: 0.9873 - val_iou_score: 0.7947
# Epoch 227/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7656 - accuracy: 0.9954 - iou_score: 0.8996 - val_loss: 0.7951 - val_accuracy: 0.9872 - val_iou_score: 0.7929
# Epoch 228/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7655 - accuracy: 0.9954 - iou_score: 0.9004 - val_loss: 0.7962 - val_accuracy: 0.9872 - val_iou_score: 0.7873
# Epoch 229/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7654 - accuracy: 0.9954 - iou_score: 0.9007 - val_loss: 0.7941 - val_accuracy: 0.9874 - val_iou_score: 0.7982
# Epoch 230/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7655 - accuracy: 0.9954 - iou_score: 0.9001 - val_loss: 0.7971 - val_accuracy: 0.9868 - val_iou_score: 0.7829
# Epoch 231/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7655 - accuracy: 0.9954 - iou_score: 0.9002 - val_loss: 0.7944 - val_accuracy: 0.9875 - val_iou_score: 0.7972
# Epoch 232/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7655 - accuracy: 0.9953 - iou_score: 0.9000 - val_loss: 0.7939 - val_accuracy: 0.9875 - val_iou_score: 0.7997
# Epoch 233/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7654 - accuracy: 0.9954 - iou_score: 0.9009 - val_loss: 0.7937 - val_accuracy: 0.9877 - val_iou_score: 0.8000
# Epoch 234/250
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7655 - accuracy: 0.9953 - iou_score: 0.9002 - val_loss: 0.7932 - val_accuracy: 0.9878 - val_iou_score: 0.8022
# Epoch 235/250
# 667/667 [==============================] - 84s 126ms/step - loss: 0.7655 - accuracy: 0.9954 - iou_score: 0.9005 - val_loss: 0.7936 - val_accuracy: 0.9876 - val_iou_score: 0.8003
# Epoch 236/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7656 - accuracy: 0.9954 - iou_score: 0.8999 - val_loss: 0.7929 - val_accuracy: 0.9876 - val_iou_score: 0.8072
# Epoch 237/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7656 - accuracy: 0.9953 - iou_score: 0.8995 - val_loss: 0.7936 - val_accuracy: 0.9873 - val_iou_score: 0.8035
# Epoch 238/250
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7654 - accuracy: 0.9954 - iou_score: 0.9011 - val_loss: 0.7935 - val_accuracy: 0.9872 - val_iou_score: 0.8049
# Epoch 239/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7654 - accuracy: 0.9954 - iou_score: 0.9010 - val_loss: 0.7945 - val_accuracy: 0.9869 - val_iou_score: 0.7968
# Epoch 240/250
# 667/667 [==============================] - 85s 128ms/step - loss: 0.7654 - accuracy: 0.9954 - iou_score: 0.9010 - val_loss: 0.7957 - val_accuracy: 0.9866 - val_iou_score: 0.7904
# Epoch 241/250
# 667/667 [==============================] - 85s 128ms/step - loss: 0.7656 - accuracy: 0.9954 - iou_score: 0.8997 - val_loss: 0.7952 - val_accuracy: 0.9870 - val_iou_score: 0.7924
# Epoch 242/250
# 667/667 [==============================] - 86s 128ms/step - loss: 0.7656 - accuracy: 0.9953 - iou_score: 0.8998 - val_loss: 0.7949 - val_accuracy: 0.9873 - val_iou_score: 0.7943
# Epoch 243/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7655 - accuracy: 0.9953 - iou_score: 0.9000 - val_loss: 0.7940 - val_accuracy: 0.9875 - val_iou_score: 0.7978
# Epoch 244/250
# 667/667 [==============================] - 83s 125ms/step - loss: 0.7655 - accuracy: 0.9954 - iou_score: 0.9008 - val_loss: 0.7947 - val_accuracy: 0.9875 - val_iou_score: 0.7942
# Epoch 245/250
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7655 - accuracy: 0.9954 - iou_score: 0.9009 - val_loss: 0.7949 - val_accuracy: 0.9874 - val_iou_score: 0.7934
# Epoch 246/250
# 667/667 [==============================] - 85s 128ms/step - loss: 0.7653 - accuracy: 0.9954 - iou_score: 0.9012 - val_loss: 0.7957 - val_accuracy: 0.9874 - val_iou_score: 0.7894
# Epoch 247/250
# 667/667 [==============================] - 84s 125ms/step - loss: 0.7654 - accuracy: 0.9954 - iou_score: 0.9006 - val_loss: 0.7958 - val_accuracy: 0.9874 - val_iou_score: 0.7886
# Epoch 248/250
# 667/667 [==============================] - 86s 129ms/step - loss: 0.7655 - accuracy: 0.9954 - iou_score: 0.9001 - val_loss: 0.7954 - val_accuracy: 0.9874 - val_iou_score: 0.7905
# Epoch 249/250
# 667/667 [==============================] - 85s 127ms/step - loss: 0.7653 - accuracy: 0.9955 - iou_score: 0.9016 - val_loss: 0.7948 - val_accuracy: 0.9874 - val_iou_score: 0.7938
# Epoch 250/250
# 667/667 [==============================] - 84s 125ms/step - loss: 0.7655 - accuracy: 0.9954 - iou_score: 0.9000 - val_loss: 0.7942 - val_accuracy: 0.9869 - val_iou_score: 0.7973

# %%
#plot the training and validation IoU and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from keras.models import load_model

#Load model for prediction or continue training

#For continuing training....
#The following gives an error: Unknown loss function: dice_loss_plus_1focal_loss
#This is because the model does not save loss function and metrics. So to compile and 
#continue training we need to provide these as custom_objects.

# my_model = load_model('saved_models/brats_3d_100epochs_simple_unet_weighted_dice.hdf5')

#So let us add the loss as custom object... but the following throws another error...
#Unknown metric function: iou_score

# my_model = load_model('saved_models/brats_3d_100epochs_simple_unet_weighted_dice.hdf5', 
#                       custom_objects={'dice_loss_plus_1focal_loss': total_loss})

#Now, let us add the iou_score function we used during our initial training
my_model = load_model('brats_2020_2021_3d_final_250.hdf5', 
                      custom_objects={'dice_loss_plus_1focal_loss': total_loss,
                                      'iou_score':sm.metrics.IOUScore(threshold=0.5)})

#Now all set to continue the training process. 
history2=my_model.fit(train_img_datagen,
          steps_per_epoch=steps_per_epoch,
          epochs=1,
          verbose=1,
          validation_data=val_img_datagen,
          validation_steps=val_steps_per_epoch,
          )
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 2025-04-28 20:23:30.358913: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 667/667 [==============================] - ETA: 0s - loss: 0.7653 - accuracy: 0.9955 - iou_score: 0.9016
# 2025-04-28 20:24:48.732840: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 667/667 [==============================] - 83s 124ms/step - loss: 0.7653 - accuracy: 0.9955 - iou_score: 0.9016 - val_loss: 0.7927 - val_accuracy: 0.9875 - val_iou_score: 0.8056

# %%
my_model = load_model('brats_2020_2021_3d_final_250.hdf5', 
                      compile=False)


#Verify IoU on a batch of images from the test dataset
#Using built in keras function for IoU
#Only works on TF > 2.0
from keras.metrics import MeanIoU

batch_size=8 #Check IoU for a batch of images
test_img_datagen = imageLoader(val_img_dir, val_img_list, 
                                val_mask_dir, val_mask_list, batch_size)

#Verify generator.... In python 3 next() is renamed as __next__()
test_image_batch, test_mask_batch = test_img_datagen.__next__()

test_mask_batch_argmax = np.argmax(test_mask_batch, axis=4)
test_pred_batch = my_model.predict(test_image_batch)
test_pred_batch_argmax = np.argmax(test_pred_batch, axis=4)

n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(test_pred_batch_argmax, test_mask_batch_argmax)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# 1/1 [==============================] - 5s 5s/step
# Mean IoU = 0.8854991

# %%
#Predict on a few test images, one at a time
#Try images: 
from keras.models import load_model 

my_model = load_model('brats_2020_2021_3d_final_250.hdf5', compile=False) 

import numpy as np 

# img_num = 57
# img_num = 143
# img_num = 165 never 
img_num = 54

test_img = np.load("2020_2021_Validation/images/image_"+str(img_num)+".npy")

test_mask = np.load("2020_2021_Validation/masks/mask_"+str(img_num)+".npy")
test_mask_argmax=np.argmax(test_mask, axis=3)

test_img_input = np.expand_dims(test_img, axis=0)
test_prediction = my_model.predict(test_img_input)
test_prediction_argmax=np.argmax(test_prediction, axis=4)[0,:,:,:]


# print(test_prediction_argmax.shape)
# print(test_mask_argmax.shape)
# print(np.unique(test_prediction_argmax))


#Plot individual slices from test predictions for verification
from matplotlib import pyplot as plt
import random

#n_slice=random.randint(0, test_prediction_argmax.shape[2])
n_slice = 55
plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,n_slice,1], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_argmax[:,:,n_slice])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction_argmax[:,:, n_slice])
plt.show()
# Out:
# 1/1 [==============================] - 0s 170ms/step
